# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install einops
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting einops
#   Downloading einops-0.4.1-py3-none-any.whl (28 kB)
# Installing collected packages: einops
# Successfully installed einops-0.4.1

# %% [markdown]
# ## Image Captioning With gMLP

# %%
import einops

# %%
import string
import numpy as np
import pandas as pd
from numpy import array
from PIL import Image
import pickle
import json
import random
import collections

import matplotlib.pyplot as plt
import sys, time, os, warnings
warnings.filterwarnings("ignore")
import re

import tensorflow as tf
from tqdm import tqdm
from nltk.translate.bleu_score import sentence_bleu

from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense, BatchNormalization
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Embedding
from tensorflow.keras.layers import Dropout
# from tensorflow.keras.layers import Add
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.preprocessing.text import Tokenizer

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split

# %%
# annotation_file = '/content/drive/MyDrive/Senior_Project/mscoco/annotations/captions_train2014.json' #'/datasets/mscoco/annotations/captions_train2014.json' #'annotations/captions_train2014.json' 
# PATH = '/content/drive/MyDrive/Senior_Project/mscoco/train2014/' #'/datasets/mscoco/train2014/' # 'train2014/'

# %%
# Download caption annotation files
annotation_folder = '/annotations/'
if not os.path.exists(os.path.abspath('.') + annotation_folder):
  annotation_zip = tf.keras.utils.get_file('captions.zip',
                                           cache_subdir=os.path.abspath('.'),
                                           origin='http://images.cocodataset.org/annotations/annotations_trainval2014.zip',
                                           extract=True)
  annotation_file = os.path.dirname(annotation_zip)+'/annotations/captions_train2014.json'
  os.remove(annotation_zip)

# Download image files
image_folder = '/train2014/'
if not os.path.exists(os.path.abspath('.') + image_folder):
  image_zip = tf.keras.utils.get_file('train2014.zip',
                                      cache_subdir=os.path.abspath('.'),
                                      origin='http://images.cocodataset.org/zips/train2014.zip',
                                      extract=True)
  PATH = os.path.dirname(image_zip) + image_folder
  os.remove(image_zip)
else:
  PATH = os.path.abspath('.') + image_folder
# Out:
# Downloading data from http://images.cocodataset.org/annotations/annotations_trainval2014.zip
# 252878848/252872794 [==============================] - 8s 0us/step
# 252887040/252872794 [==============================] - 8s 0us/step
# Downloading data from http://images.cocodataset.org/zips/train2014.zip
# 13510574080/13510573713 [==============================] - 387s 0us/step
# 13510582272/13510573713 [==============================] - 387s 0us/step

# %%
with open(annotation_file, 'r') as f:
    annotations = json.load(f)

# %%
# Group all captions together having the same image ID.
image_path_to_caption = collections.defaultdict(list)
for val in annotations['annotations']:
  caption = f"<start> {val['caption']} <end>"
  image_path = PATH + 'COCO_train2014_' + '%012d.jpg' % (val['image_id'])
  image_path_to_caption[image_path].append(caption)

# %%
image_paths = list(image_path_to_caption.keys())
random.shuffle(image_paths)

# Select the first 6000 image_paths from the shuffled set.
# Approximately each image id has 5 captions associated with it, so that will
# lead to 30,000 examples.
train_image_paths = image_paths[:6000]
print(len(train_image_paths))
# Out:
# 6000

# %%
train_captions = []
img_name_vector = []

for image_path in train_image_paths:
  caption_list = image_path_to_caption[image_path]
  train_captions.extend(caption_list)
  img_name_vector.extend([image_path] * len(caption_list))

# %%
assert len(train_captions) == len(img_name_vector)

# %%
# from pathlib import Path

# my_file = Path(img_name_vector[0])

# %%
# my_file.exists()

# %%
print(train_captions[0])
Image.open(img_name_vector[0])
# Out:
# <start> No image is appearing above this box to describe. <end>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x432 at 0x7F33B40EC8D0>

# %% [markdown]
# ## Preprocess Image

# %%
def load_image(image_path):
    img = tf.io.read_file(image_path)
    img = tf.io.decode_jpeg(img, channels=3)
    img = tf.keras.layers.Resizing(299, 299)(img)
    img = tf.keras.applications.inception_v3.preprocess_input(img)
    return img, image_path

# %% [markdown]
# ## InceptionV3 (2019) as an Encoder

# %%
# image_model = tf.keras.applications.InceptionV3(include_top=False,
#                                                 weights='imagenet')
# new_input = image_model.input
# hidden_layer = image_model.layers[-1].output

# image_features_extract_model = tf.keras.Model(new_input, hidden_layer)

# %%
# from tqdm import tqdm

# %%
# # Get unique images
# encode_train = sorted(set(img_name_vector))

# # Feel free to change batch_size according to your system configuration
# image_dataset = tf.data.Dataset.from_tensor_slices(encode_train)
# image_dataset = image_dataset.map(
#   load_image, num_parallel_calls=tf.data.AUTOTUNE).batch(16)

# for img, path in tqdm(image_dataset):
#   batch_features = image_features_extract_model(img)
#   batch_features = tf.reshape(batch_features,
#                               (batch_features.shape[0], -1, batch_features.shape[3]))

#   for bf, p in zip(batch_features, path):
#     path_of_feature = p.numpy().decode("utf-8")
#     np.save(path_of_feature, bf.numpy())

# %% [markdown]
# ## Vectorization

# %%
caption_dataset = tf.data.Dataset.from_tensor_slices(train_captions)

# We will override the default standardization of TextVectorization to preserve
# "<>" characters, so we preserve the tokens for the <start> and <end>.
def standardize(inputs):
  inputs = tf.strings.lower(inputs)
  return tf.strings.regex_replace(inputs,
                                  r"!\"#$%&\(\)\*\+.,-/:;=?@\[\\\]^_`{|}~", "")

# Max word count for a caption.
max_length = 50 
# Use the top 5000 words for a vocabulary.
vocabulary_size = 5000
tokenizer = tf.keras.layers.TextVectorization(
    max_tokens=vocabulary_size,
    standardize=standardize,
    output_sequence_length=max_length)
# Learn the vocabulary from the caption data.
tokenizer.adapt(caption_dataset)

# %%
# Create the tokenized vectors
cap_vector = caption_dataset.map(lambda x: tokenizer(x))

# %%
# Create mappings for words to indices and indicies to words.
word_to_index = tf.keras.layers.StringLookup(
    mask_token="",
    vocabulary=tokenizer.get_vocabulary())
index_to_word = tf.keras.layers.StringLookup(
    mask_token="",
    vocabulary=tokenizer.get_vocabulary(),
    invert=True)

# %% [markdown]
# ## Split the data into training and testing

# %%
img_to_cap_vector = collections.defaultdict(list)
for img, cap in zip(img_name_vector, cap_vector):
  img_to_cap_vector[img].append(cap)

# Create training and validation sets using an 60-20-20 split randomly.
img_keys = list(img_to_cap_vector.keys())
random.shuffle(img_keys)

val_slice_index = int(len(img_keys)*0.6)
test_slice_index = int(len(img_keys)*0.8)
img_name_train_keys, img_name_val_keys, img_name_test_keys = img_keys[:val_slice_index], img_keys[val_slice_index: test_slice_index], img_keys[test_slice_index:]

img_name_train = []
cap_train = []
for imgt in img_name_train_keys:
  capt_len = len(img_to_cap_vector[imgt])
  img_name_train.extend([imgt] * capt_len)
  cap_train.extend(img_to_cap_vector[imgt])

img_name_val = []
cap_val = []
for imgv in img_name_val_keys:
  capv_len = len(img_to_cap_vector[imgv])
  img_name_val.extend([imgv] * capv_len)
  cap_val.extend(img_to_cap_vector[imgv])

img_name_test = []
cap_test = []
for imgv in img_name_test_keys:
  capte_len = len(img_to_cap_vector[imgv])
  img_name_test.extend([imgv] * capte_len)
  cap_test.extend(img_to_cap_vector[imgv])

# %%
len(img_name_train), len(cap_train), len(img_name_val), len(cap_val), len(img_name_test), len(cap_test)
# Out:
# (18008, 18008, 6004, 6004, 6001, 6001)

# %% [markdown]
# ## Create a tf.data dataset for training

# %%
# Feel free to change these parameters according to your system's configuration

BATCH_SIZE = 64
BUFFER_SIZE = 1000
embedding_dim = 256
units = 512
num_steps = len(img_name_train) // BATCH_SIZE
# Shape of the vector extracted from InceptionV3 is (64, 2048)
# These two variables represent that vector shape
features_shape = 2048
attention_features_shape = 64

IMAGE_SIZE = (299, 299)

# %%
# Desired image dimensions
IMAGE_SIZE = (299, 299)

# Vocabulary size
VOCAB_SIZE = 5000 # 10000

# Fixed length allowed for any sequence
SEQ_LENGTH = 100 # 25

# Dimension for the image embeddings and token embeddings
EMBED_DIM = 512

# Per-layer units in the feed-forward network
FF_DIM = 512

# Other training parameters
BATCH_SIZE = 64
EPOCHS = 30
AUTOTUNE = tf.data.AUTOTUNE

# %%
# Load the numpy files
def map_func(img_name, cap):
    img_tensor = np.load(img_name.decode('utf-8')+'.npy')
    return img_tensor, cap

# %%
# dataset = tf.data.Dataset.from_tensor_slices((img_name_train, cap_train))

# # Use map to load the numpy files in parallel
# dataset = dataset.map(lambda item1, item2: tf.numpy_function(
#           map_func, [item1, item2], [tf.float32, tf.int64]),
#           num_parallel_calls=tf.data.AUTOTUNE)

# # # Shuffle and batch
# dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE) # Batch_size * (img_name_train, cap_train)
# dataset = dataset.prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
def decode_and_resize(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, IMAGE_SIZE)
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = tf.keras.applications.inception_v3.preprocess_input(img)
    return img


def process_input(img_path, captions):
    return decode_and_resize(img_path), captions


def make_dataset(images, captions):
    dataset = tf.data.Dataset.from_tensor_slices((images, captions))
    dataset = dataset.shuffle(len(images))
    dataset = dataset.map(process_input, num_parallel_calls=AUTOTUNE)
    dataset = dataset.batch(BATCH_SIZE).prefetch(AUTOTUNE)

    return dataset


# Pass the list of images and the list of corresponding captions
train_dataset = make_dataset(img_name_train, cap_train)

valid_dataset = make_dataset(img_name_val, cap_val)

test_dataset = make_dataset(img_name_test, cap_test)

# %%
train_dataset
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 299, 299, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, 50), dtype=tf.int64, name=None))>

# %% [markdown]
# ## CNN Encoder

# %%
# class CNN_Encoder(tf.keras.Model):
#     # Since you have already extracted the features and dumped it
#     # This encoder passes those features through a Fully connected layer
#     def __init__(self, embedding_dim):
#         super(CNN_Encoder, self).__init__()
#         # shape after fc == (batch_size, 64, embedding_dim)
#         self.fc = tf.keras.layers.Dense(embedding_dim)

#     def call(self, x):
#         x = self.fc(x)
#         x = tf.nn.relu(x)
#         return x

# %% [markdown]
# ## gMLP

# %% [markdown]
# ### gMLP Architecture
# From https://github.com/lucidrains/g-mlp-pytorch

# %%
import tensorflow as tf
from tensorflow.keras.initializers import RandomUniform
from tensorflow.keras.layers import Layer, LayerNormalization
from einops import rearrange, repeat
from random import randrange

# %%
def exists(val):
    return val is not None

# %%
def dropout_layers(layers, prob_survival):
    if prob_survival == 1:
        return layers

    num_layers = len(layers)
    to_drop = tf.random.uniform([num_layers], minval=0., maxval=1.) > prob_survival

    # make sure at least one layer makes it
    if all(to_drop):
        rand_index = randrange(num_layers)
        to_drop[rand_index] = False

    layers = [layer for (layer, drop) in zip(layers, to_drop) if not drop]
    return layers

# %%
class Attention(tf.keras.layers.Layer):
    def __init__(self, d_out, d_attn, causal = False):
        super().__init__()
        
        self.d_attn = d_attn
        self.scale = d_attn ** -0.5

        self.proj_in = tf.keras.layers.Dense(3 * d_attn)
        self.proj_out = tf.keras.layers.Dense(d_out)
        self.causal = causal

    def call(self, x):
        qkv = self.proj_in(x)
        q, k, v = tf.split(qkv, num_or_size_splits=3, axis=-1)
        w = tf.einsum('bid,bjd->bij', q, k) * self.scale

        if self.causal:
            mask = tf.ones(w.shape[-2:])

            # band_part and set_diag replace triu(1) in lucidrains' implementation
            mask = tf.linalg.band_part(mask, 0, -1)
            mask_diag = tf.linalg.diag_part(mask)
            mask = tf.linalg.set_diag(mask, tf.zeros_like(mask_diag))
            mask = tf.cast(mask, dtype=tf.bool)

            w = tf.where(mask[None, ...], tf.ones_like(w) * -q.dtype.max, w)

        a = tf.nn.softmax(w * tf.math.rsqrt(float(self.d_attn)), axis=-1)
        out = tf.einsum('bij,bjd->bid', a, v)
        return self.proj_out(out)

# %%
class SpatialGatingUnit(Layer):
    def __init__(self, 
                dim_seq, 
                causal = False, 
                activation = tf.identity, 
                heads = 1,
                init_eps = 1e-3,
                circulant_matrix = False,
                kernel_regularizer=None,
                bias_regularizer=None):
        
        super().__init__()
        self.dim_seq = dim_seq
        self.causal = causal
        self.activation = activation
        self.init_eps = init_eps / dim_seq

        self.kernel_regularizer = kernel_regularizer
        self.bias_regularizer = bias_regularizer
        self.heads = heads

        # parameters
        if circulant_matrix:
            self.circulant_pos_x = tf.ones((heads, dim_seq))
            self.circulant_pos_y = tf.ones((heads, dim_seq))

        self.circulant_matrix = circulant_matrix
        shape = (heads, dim_seq,) if circulant_matrix else (heads, dim_seq, dim_seq)
        self.shape = shape

        self.heads = heads

    def build(self, _):

        self.dense_bias = self.add_weight(
            name="sgu_dense_bias", 
            regularizer=self.bias_regularizer,
            shape=(self.heads, self.dim_seq), # 1 is the number of heads
            initializer=tf.ones
        )
        
        self.dense_weight = self.add_weight(
            name="sgu_dense_kernel", 
            regularizer=self.kernel_regularizer,
            shape=self.shape, 
            initializer=RandomUniform(minval=-self.init_eps, maxval=self.init_eps)
        )

        self.norm = LayerNormalization()

    def call(self, x, tiny_attn=None):
        device, n, h = x.device, x.shape[1], self.heads

        res, gate = tf.split(x, 2, axis=-1)
        gate = self.norm(gate)

        weight, bias = self.dense_weight, self.dense_bias
        
        if self.circulant_matrix:
            # build the circulant matrix
            dim_seq = weight.shape[-1]
            paddings = tf.constant([[0, 0], [0, dim_seq]])
            weight = tf.pad(weight, paddings, constant_values=0)
            weight = repeat(weight, '... n -> ... (r n)', r = dim_seq)
            weight = tf.reshape(weight[:, :-dim_seq], [h, dim_seq, 2 * dim_seq - 1])
            weight = weight[:, :, (dim_seq - 1):]

            # give circulant matrix absolute position awareness

            pos_x, pos_y = self.circulant_pos_x, self.circulant_pos_y
            weight = weight * rearrange(pos_x, 'h i -> h i ()') * rearrange(pos_y, 'h j -> h () j')
        
        if self.causal:
            weight, bias = weight[:, :n, :n], bias[:,:n]
            mask = tf.ones(weight.shape[-2:])

            # band_part and set_diag replace triu(1) in lucidrains' implementation
            mask = tf.linalg.band_part(mask, 0, -1)
            mask_diag = tf.linalg.diag_part(mask)
            mask = tf.linalg.set_diag(mask, tf.zeros_like(mask_diag))
            mask = tf.cast(mask, dtype=tf.bool)

            mask = rearrange(mask, 'i j -> () i j')
            weight = tf.where(mask, tf.zeros_like(weight), weight)


        gate = rearrange(gate, 'b n (h d) -> b h n d', h = h)


        gate = tf.einsum('bhnd, hmn->bhmd', gate, weight)
        gate = gate + rearrange(bias, 'h n -> () h n ()')

        gate = rearrange(gate, 'b h n d -> b n (h d)')
        
        if exists(tiny_attn):
            gate = gate + tiny_attn

        return self.activation(gate) * res # dimension at axis = -1 gets halved

# %%
# ***** gMLP-block works as a self-attention *****
class gMLP_Block(tf.keras.Model):
    def __init__(self, d_ffn, d_model, seq_len, heads=1, circulant_matrix = False, causal=False, attn_dim=None, act=tf.identity):
        super().__init__()
        
        self.norm_layer = tf.keras.layers.LayerNormalization(axis=-1)
        
        self.proj_in = tf.keras.layers.Dense(d_ffn, activation='gelu')

        # attention
        self.tiny_attn = Attention(d_ffn // 2, attn_dim, causal=causal) if attn_dim else None

        self.sgu = SpatialGatingUnit(seq_len, causal=causal, activation=act, heads=heads, circulant_matrix = circulant_matrix)
        self.proj_out = tf.keras.layers.Dense(d_model)
        
    def call(self, x):
        # word_embedding
        shortcut = x

        x = self.norm_layer(x)

        attn = self.tiny_attn(x) if self.tiny_attn else None

        x = self.proj_in(x)
        x = self.sgu(x, tiny_attn=attn)
        x = self.proj_out(x)
        
        x = x + shortcut
        
        return x

# %%
class gMLPDecoderLayer(tf.keras.layers.Layer):
    """
      Combine text embedding with image features
    """
    def __init__(self, d_ffn, d_model, seq_len, heads=1, circulant_matrix = False, causal=False, attn_dim=None, act=tf.identity):
        super().__init__()
        
        self.gmlp_block = gMLP_Block(d_ffn=d_ffn, d_model=d_model, heads=heads, seq_len=seq_len, attn_dim=attn_dim, causal=causal, act=act, circulant_matrix=circulant_matrix)
        # for image
        self.gmlp_block_2 = gMLP_Block(d_ffn=d_ffn, d_model=d_model, heads=heads, seq_len=seq_len, attn_dim=attn_dim, causal=causal, act=act, circulant_matrix=circulant_matrix)

    def call(self, x, enc_output):
        seq_len = tf.shape(x)[1]
        
        # look ahead mask
        out = self.gmlp_block(x)

        enc_output = tf.expand_dims(enc_output, axis=1)
        out = enc_output + out


        
        # --------------------------------------------------------------------------------------------------------------------------------------------------------------------------
        # out = self.gmlp_block_2(out)
        # --------------------------------------------------------------------------------------------------------------------------------------------------------------------------

        return out

# %% [markdown]
# ### gMLP NLP

# %%
# top k filtering

def top_k(logits, thres = 0.9):
    k = int((1 - thres) * logits.shape[-1])
    val, ind = tf.math.top_k(logits, k)
    probs = tf.fill(logits.shape, float('-inf'))
    probs.scatter_(1, ind, val)
    return probs

# %%
def eval_decorator(fn):
    def inner(model, *args, **kwargs):
        out = fn(model, *args, **kwargs)
        return out
    return inner

# %%
# import tensorflow_probability as tfp

# %%
# class AutogressiveWrapper(tf.keras.Model):
#     def __init__(self, net, ignore_index = -100, pad_value=0):
#         super().__init__()
#         self.pad_value = pad_value
#         self.ignore_index = ignore_index

#         self.net = net
#         self.max_seq_len = net.seq_len

#     \@eval_decorator
#     def generate(self, start_tokens, seq_len, eos_token = None, temperature = 1., filter_logits_fn = top_k, filter_thres = 0.9, **kwargs):
#         num_dims = len(start_tokens.shape)

#         if num_dims == 1:
#             start_tokens = start_tokens[None, :]

#         b, t = start_tokens.shape

#         out = start_tokens

#         for _ in range(seq_len):
#             x = out[:, -self.max_seq_len:]

#             # TODO: pass input features
#             logits = self.net(x, **kwargs)[:, -1, :]

#             filtered_logits = top_k(logits, thres = filter_thres)
#             probs = tf.nn.softmax(filtered_logits / temperature, dim=-1)

#             dist = tfp.distributions.Multinomial(1, probs=probs)
#             sample = tf.where(tf.equal(dist.sample(1)[0], 1))[0]

#             out = tf.concat([out, sample], axis=-1)

#             if eos_token is not None and (sample == eos_token).all():
#                 break

#         out = out[:, t:]

#         if num_dims == 1:
#             out = out.squeeze(0)
#         return out

#     def call(self, x, **kwargs):
#         xi, xo = x[:, :-1], x[:, 1:]
#         out = self.net(xi, **kwargs)
#         loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')

#         loss = loss_function(xo, tf.transpose(out, perm=[1, 2]))
#         return loss

# %%
class gMLPNLP(tf.keras.Model):
    def __init__(self, *, num_tokens=None, embedding_dim, depth, seq_len, heads=1, ff_mult=4, attn_dim=None, prob_survival = 1., causal=False, circulant_matrix = False, act=tf.identity):
        super().__init__()
        
        assert (embedding_dim % heads) == 0, 'dimension must be divisible by number of heads'

        dim_ff = embedding_dim * ff_mult
        self.seq_len = seq_len
        self.prob_survival = prob_survival
        self.embedding_dim = embedding_dim
        
        self.to_embed = tf.keras.layers.Embedding(num_tokens, embedding_dim) if num_tokens else tf.identity

        self.gmlp_layers = [gMLPDecoderLayer(d_ffn=dim_ff, d_model=embedding_dim, heads=heads, seq_len=seq_len, attn_dim=attn_dim, causal=causal, act=act, circulant_matrix=circulant_matrix) for i in range(depth)]

        self.to_logits = tf.keras.Sequential([
            tf.keras.layers.LayerNormalization(),
            tf.keras.layers.Dense(num_tokens)
        ]) if num_tokens else tf.identity
        
    def call(self, x, img_features, is_training=True):        
        x = self.to_embed(x) # batch_size, seq_len, embedding_dim
        x *= tf.math.sqrt(tf.cast(self.embedding_dim, tf.float32))

        gmlp_layers = self.gmlp_layers if not is_training else dropout_layers(self.gmlp_layers, self.prob_survival)
        
        for layer in gmlp_layers:
            x = layer(x, img_features)

        out = x
        return self.to_logits(out) # (batch_size, tar_seq_len, target_vocab_size)

# %% [markdown]
# ## gMLPVision

# %%
def pair(val):
    return (val, val) if not isinstance(val, tuple) else val

# %%
class RearrangeLayer(tf.keras.layers.Layer):
    def __init__(self, patch_height, patch_width):
        super().__init__()
        self.patch_height = patch_height
        self.patch_width = patch_width

    def call(self, x):
        return rearrange(x, 'b (h p1) (w p2) c -> b (h w) (c p1 p2)', p1 = self.patch_height, p2 = self.patch_width)

# %%
class ReduceLayer(tf.keras.layers.Layer):
    def __init__(self):
        super().__init__()

    def call(self, x):
        return tf.reduce_mean(x, 1)

# %%
class gMLPVision(tf.keras.Model):
    def __init__(
        self,
        *,
        image_size,
        patch_size,
        dim,
        depth,
        heads = 1,
        ff_mult=4, 
        channels = 3,
        attn_dim = None,
        prob_survival = 1.
    ):
        super().__init__()
        assert (dim % heads) == 0, 'dimension must be divisible by number of heads'

        image_height, image_width = pair(image_size)
        patch_height, patch_width = pair(patch_size)
        assert (image_height % patch_height) == 0 and (image_width % patch_width) == 0, 'image height and width must be divisible by patch size'
        num_patches = (image_height // patch_height) * (image_width // patch_width)

        dim_ff = dim * ff_mult

        self.to_patch_embed = tf.keras.Sequential(
            [
             RearrangeLayer(patch_height, patch_width), 
             tf.keras.layers.Dense(dim)]
        )

        self.prob_survival = prob_survival

        self.gmlp_layers = [gMLP_Block(d_model=dim, heads=heads, d_ffn=dim_ff, seq_len=num_patches, attn_dim=attn_dim) for _ in range(depth)]

        self.to_logits = tf.keras.Sequential(
          [tf.keras.layers.LayerNormalization(),
           ReduceLayer()]
        )
    def call(self, x, is_training=True):
        x = self.to_patch_embed(x)

        gmlp_layers = self.gmlp_layers if not is_training else dropout_layers(self.gmlp_layers, self.prob_survival)
        x = tf.keras.Sequential(gmlp_layers)(x)
        return self.to_logits(x)

# %% [markdown]
# ### Simple Test

# %%
# model = gMLPVision(
#     image_size = 256,
#     patch_size = 16,
#     dim = 512,
#     depth = 6
# )

# img = tf.random.normal((1, 256, 256, 3)) # batch size, image_width, image_height, channel
# logits = model(img, is_training=True) # (1, 1000)

# %%
# model = gMLPNLP(
#     num_tokens = 20000,
#     embedding_dim = 512,
#     depth = 6,
#     seq_len = 256,
#     circulant_matrix = True,      # use circulant weight matrix for linear increase in parameters in respect to sequence length
#     act = tf.math.tanh               # activation for spatial gate (defaults to identity)
# )

# x = tf.random.uniform((1, 256), minval=0, maxval=20000)
# logits = model(x) # (1, 256, 20000)

# %%
# logits.shape

# %% [markdown]
# ## Model Training

# %% [markdown]
# ### Model Hyperparameters

# %%
num_layer = 1
d_model = 512
num_heads = 8
target_vocab_size = VOCAB_SIZE + 1 # + unknown token

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
   def __init__(self, d_model, warmup_steps=4000):
      super(CustomSchedule, self).__init__()
      self.d_model = d_model
      self.d_model = tf.cast(self.d_model, tf.float32)
      self.warmup_steps = warmup_steps

   def __call__(self, step):
      arg1 = tf.math.rsqrt(step)
      arg2 = step * (self.warmup_steps ** -1.5)
      return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)

# %%
learning_rate = CustomSchedule(d_model)
optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98,
                                    epsilon=1e-9)

# %%
train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='train_accuracy')

val_loss = tf.keras.metrics.Mean(name='val_loss')
val_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='val_accuracy')

# cnn_model = get_cnn_model()

encoder = gMLPVision(
    image_size = IMAGE_SIZE,
    patch_size = 13,
    dim = 512,
    depth = num_layer
    #,
    #attn_dim=64
)
decoder = gMLPNLP(num_tokens=target_vocab_size, depth=num_layer, embedding_dim=d_model, heads=num_heads, seq_len=SEQ_LENGTH, causal=True, circulant_matrix=True)#, #attn_dim=64) # attn_dim=64

# %% [markdown]
# ### Checkpoint

# %%
checkpoint_path = '/content/drive/MyDrive/My Senior Project Spring 2022/checkpoint/gMLP_mscoco_commented'

ckpt = tf.train.Checkpoint(encoder=encoder,
                           decoder=decoder,
                           optimizer=optimizer)
ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=1)

# %%
start_epoch = 0
if ckpt_manager.latest_checkpoint:
    print(ckpt_manager.latest_checkpoint)
    start_epoch = int(ckpt_manager.latest_checkpoint.split('-')[-1])
    # restoring the latest checkpoint in checkpoint_path
    ckpt.restore(ckpt_manager.latest_checkpoint)
# Out:
# /content/drive/MyDrive/My Senior Project Spring 2022/checkpoint/gMLP_mscoco_commented/ckpt-20

# %%
print(start_epoch)
# Out:
# 20

# %% [markdown]
# ### Model Training

# %%
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')

def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)
    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask
    return tf.reduce_sum(loss_)/tf.reduce_sum(mask)

# %%
def train_step(img_tensor, tar, is_training):
    # 1. Get image embeddings
    # img_tensor = cnn_model(img_tensor)

    # 2. Pass each of the five captions one by one to the decoder
    # along with the encoder outputs and compute the loss as well as accuracy
    # for each caption.
    # num_captions_per_image = 5
    all_captions_loss = 0
    tar_inp = tar[:, :-1]
    tar_real = tar[:, 1:]

    if is_training:
        with tf.GradientTape() as tape:
            features = encoder(img_tensor, is_training)
            predictions = decoder(tar_inp, features, is_training)

            loss = loss_function(tar_real, predictions)
            all_captions_loss += loss

            trainable_variables = encoder.trainable_variables + decoder.trainable_variables
            gradients = tape.gradient(loss, trainable_variables)   
            optimizer.apply_gradients(zip(gradients, trainable_variables))
    
            train_loss(loss)
            train_accuracy(tar_real, predictions)
    else:
        features = encoder(img_tensor, is_training)
        predictions = decoder(tar_inp, features, is_training)
        loss = loss_function(tar_real, predictions)

        val_loss(loss)
        val_accuracy(tar_real, predictions)

# %%
train_losses = []
train_accuracies = []

val_losses = []
val_accuracies = []

for epoch in range(start_epoch, 21):
   start = time.time()
   train_loss.reset_states()
   train_accuracy.reset_states()
   for (batch, (img_tensor, tar)) in enumerate(train_dataset):
      train_step(img_tensor, tar, True)
      if batch % 50 == 0:
         print ('Epoch {} Batch {} Loss {:.4f} Accuracy {:.4f}'.format(
         epoch + 1, batch, train_loss.result(), train_accuracy.result()))
   train_losses.append(train_loss.result() / 5)
   train_accuracies.append(train_accuracy.result() / 5)

   # validation
   val_loss.reset_states()
   val_accuracy.reset_states()
   for (batch, (img_tensor, tar)) in enumerate(valid_dataset):
     train_step(img_tensor, tar, False)
     if batch % 50 == 0:
         print ('Epoch {} Batch {} Validation Loss {:.4f} Validation Accuracy {:.4f}'.format(
         epoch + 1, batch, val_loss.result(), val_accuracy.result()))

   val_losses.append(val_loss.result() / 5)
   val_accuracies.append(val_accuracy.result() / 5)
   if epoch % 10 == 0:
      ckpt_manager.save(checkpoint_number=epoch)     

   print ('Epoch {} Loss {:.4f} Accuracy {:.4f}'.format(epoch + 1,
                                               train_loss.result(),
                                               train_accuracy.result()))
   
   print ('Epoch {} Validation Loss {:.4f} Validation Accuracy {:.4f}'.format(epoch + 1,
                                               val_loss.result(),
                                               val_accuracy.result()))
   
   print ('Time taken for 1 epoch: {} secs\n'.format(time.time() - start))
# Out:
# Epoch 21 Batch 0 Loss 6.9386 Accuracy 0.0459
# Epoch 21 Batch 50 Loss 5.0043 Accuracy 0.0651
# Epoch 21 Batch 100 Loss 4.6189 Accuracy 0.0715
# Epoch 21 Batch 150 Loss 4.4159 Accuracy 0.0748
# Epoch 21 Batch 200 Loss 4.2643 Accuracy 0.0772
# Epoch 21 Batch 250 Loss 4.1467 Accuracy 0.0791
# Epoch 21 Batch 0 Validation Loss 3.8682 Validation Accuracy 0.0829
# Epoch 21 Batch 50 Validation Loss 3.6297 Validation Accuracy 0.0872
# Epoch 21 Loss 4.0912 Accuracy 0.0799
# Epoch 21 Validation Loss 3.6541 Validation Accuracy 0.0869
# Time taken for 1 epoch: 86.18969631195068 secs

# %% [markdown]
# ## Evaluate

# %%
from nltk.translate.bleu_score import sentence_bleu

# %%
def evaluate(image):
   temp_input = tf.expand_dims(decode_and_resize(image), 0)
   img_tensor_val = temp_input
  #  img_tensor_val = cnn_model(temp_input)
  #  img_tensor_val = tf.reshape(img_tensor_val, (img_tensor_val.shape[0], -1, img_tensor_val.shape[3]))
   start_token = word_to_index(tf.constant('<start>'))
   end_token = word_to_index(tf.constant('<end>'))
   decoder_input = [start_token]
   output = tf.expand_dims(decoder_input, 0) #tokens
   result = [] #word list

   for i in range(100):
      features = encoder(img_tensor_val)
      predictions = decoder(output, features)

      predictions = predictions[: ,-1:, :]  # (batch_size, 1, vocab_size)
      predicted_id = tf.cast(tf.argmax(predictions, axis=-1), tf.int64)
      if predicted_id == end_token:
         return result,tf.squeeze(output, axis=0)
      result.append(tf.compat.as_text(index_to_word(int(predicted_id.numpy())).numpy()))
      output = tf.concat([output, predicted_id], axis=-1)

   return result,tf.squeeze(output, axis=0)

# %%
def test_single_img(id):
  image = img_name_test[id]

  caption = cap_test[id]

  bleu_scores = []
  # for caption in captions:
  real_caption = ' '.join([tf.compat.as_text(index_to_word(i).numpy()) for i in caption if i not in [0]])
  caption, result = evaluate(image)

  first = real_caption.split(' ', 1)[1]
  real_caption = first.rsplit(' ', 1)[0]

  for i in caption:
    if i=="<unk>":
        caption.remove(i)

  for i in real_caption:
    if i=="<unk>":
        real_caption.remove(i)

  result_join = ' '.join(caption)
  result_final = result_join.rsplit(' ', 1)[0]
  real_appn = []
  real_appn.append(real_caption.split())
  reference = real_appn
  candidate = caption

  # score = sentence_bleu(reference, candidate, weights=(1.0,0,0,0))
  # print(f"BLEU-1 score: {score*100}")
  # score = sentence_bleu(reference, candidate, weights=(0.5,0.5,0,0))
  # print(f"BLEU-2 score: {score*100}")
  # score = sentence_bleu(reference, candidate, weights=(0.3,0.3,0.3,0))
  # print(f"BLEU-3 score: {score*100}")
  score = sentence_bleu(reference, candidate, weights=(0.25,0.25,0.25,0.25))
  bleu_scores.append(score)
  print(f"BLEU-4 score: {score*100}")

  print ('Real Caption:', real_caption)
  print ('Predicted Caption:', ' '.join(caption))
  temp_image = np.array(Image.open(image))
  plt.imshow(temp_image)

  return np.mean(bleu_scores)

# %%
test_single_img(580)
# Out:
# BLEU-4 score: 45.91497693322865
# Real Caption: a boy that is jumping a skateboard on a ramp
# Predicted Caption: a woman is sitting on a surfboard in the ocean.
# 0.4591497693322865

# %%
bleu_scores = []
for i in range(len(img_name_test)):
  bleu_score = test_single_img(i)
  bleu_scores.append(bleu_score)

np.mean(bleu_scores)
# Out:
# BLEU-4 score: 65.29942057256105
# Real Caption: a young child cutting into a birthday cake.
# Predicted Caption: a woman is sitting on a table with her cell phone
# BLEU-4 score: 65.29942057256105
# Real Caption: a boy in stripped shirt reaching for a frosted cake.
# Predicted Caption: a woman is sitting on a table with her cell phone
# BLEU-4 score: 40.637982820134425
# Real Caption: a group of babies cutting cakes on a dining table.
# Predicted Caption: a woman is sitting on a table with her cell phone
# BLEU-4 score: 65.29942057256105
# Real Caption: a child getting into a birthday cake at a birthday party.
# Predicted Caption: a woman is sitting on a table with her cell phone
# BLEU-4 score: 65.29942057256105
# Real Caption: a young child cutting a birthday cake at a party.
# Predicted Caption: a woman is sitting on a table with her cell phone
# BLEU-4 score: 32.46679154750989
# Real Caption: a green and yellow trolley bus coming down a street
# Predicted Caption: a man is walking down a street with a [UNK]
# BLEU-4 score: 66.8740304976422
# Real Caption: a bus pulls up next to a side walk.
# Predicted Caption: a man is walking down a street with a [UNK]
# BLEU-4 score: 74.00828044922852
# Real Caption: a double decker bus is turning a corner.
# Predicted Caption: a man is walking down a street with a [UNK]
# BLEU-4 score: 79.52707287670506
# Real Caption: a double [UNK] bus on a city street
# Predicted Caption: a man is walking down a street with a [UNK]
# BLEU-4 score: 41.545589177443254
# Real Caption: a double-decker bus is driving around a [UNK] in the road.
# Predicted Caption: a man is walking down a street with a [UNK]
# BLEU-4 score: 65.29942057256105
# Real Caption: a couple of boats that are in some water
# Predicted Caption: a man riding a wave on a surfboard in the ocean.
# BLEU-4 score: 65.29942057256105
# Real Caption: a pair of boats docked at a pier is shown.
# Predicted Caption: a man riding a wave on a surfboard in the ocean.
# BLEU-4 score: 36.72056269893593
# Real Caption: three boats docked in still water with clouds in the sky.
# Predicted Caption: a man riding a wave on a surfboard in the ocean.
# BLEU-4 score: 65.29942057256105
# Real Caption: three boats are docked together on the cloudy day.
# Predicted Caption: a man riding a wave on a surfboard in the ocean.
# BLEU-4 score: 54.91004867761124
# Real Caption: some colorful boats sitting next to a dock
# Predicted Caption: a man riding a wave on a surfboard in the ocean.
# BLEU-4 score: 66.8740304976422
# Real Caption: a person jumping a skate board into the air
# Predicted Caption: a woman is sitting on a table with a [UNK]
# BLEU-4 score: 66.8740304976422
# Real Caption: a boy doing tricks on his skateboard beside his home.
# Predicted Caption: a woman is sitting on a table with a [UNK]
# BLEU-4 score: 66.8740304976422
# Real Caption: a man flying through the air while riding a skateboard.
# Predicted Caption: a woman is sitting on a table with a [UNK]
# BLEU-4 score: 60.59285518620335
# Real Caption: a guy flipping a skateboard through the air off a grass hill.
# Predicted Caption: a woman is sitting on a table with a [UNK]
# BLEU-4 score: 79.52707287670506
# Real Caption: a skateboarder is performing an [UNK] near a large house.
# Predicted Caption: a woman is sitting on a table with a [UNK]
# BLEU-4 score: 0
# Real Caption: several images of people looking at their luggage.
# Predicted Caption: a woman is holding a tennis racquet on a tennis court.
# BLEU-4 score: 0
# Real Caption: various different frames of people that are standing around luggage.
# Predicted Caption: a woman is holding a tennis racquet on a tennis court.
# BLEU-4 score: 0
# Real Caption: pictures of multiple people with their luggage at an airport.
# Predicted Caption: a woman is holding a tennis racquet on a tennis court.
# BLEU-4 score: 0
# Real Caption: this [UNK] shows [UNK] views of luggage handling in the airport and the use of luggage [UNK]
# Predicted Caption: a woman is holding a tennis racquet on a tennis court.
# BLEU-4 score: 54.91004867761124
# Real Caption: a collage of pictures inside of an airport
# Predicted Caption: a woman is holding a tennis racquet on a tennis court.
# BLEU-4 score: 31.12878027628485
# Real Caption: a man with gray hair is wearing a button up shirt and tie.
# Predicted Caption: a man is holding a frisbee in the water
# BLEU-4 score: 7.763818170390138
# Real Caption: an [UNK] picture shows a closeup of a smiling man in the foreground of a [UNK] hall with columns a couple of people and hanging decorations.
# Predicted Caption: a man is holding a frisbee in the water
# BLEU-4 score: 31.12878027628485
# Real Caption: there is a man that is wearing a white shirt and a tie
# Predicted Caption: a man is holding a frisbee in the water
# BLEU-4 score: 68.65890479690393
# Real Caption: three people are standing in a hotel [UNK]
# Predicted Caption: a man is holding a frisbee in the water
# BLEU-4 score: 32.3729563941832
# Real Caption: a man with white hair wearing a neck tie and white shirt.
# Predicted Caption: a man is holding a frisbee in the water
# BLEU-4 score: 65.37993517025207
# Real Caption: there is a jockey and a horse running on the field
# Predicted Caption: a woman is holding a frisbee in the ocean
# BLEU-4 score: 49.196255036686594
# Real Caption: the master of hounds leading the dogs out for a fox [UNK]
# Predicted Caption: a woman is holding a frisbee in the ocean
# BLEU-4 score: 68.65890479690393
# Real Caption: a rider and horse during a sporting event.
# Predicted Caption: a woman is holding a frisbee in the ocean
# BLEU-4 score: 44.02274324685413
# Real Caption: a person rides a horse while being [UNK] by a pack of dogs.
# Predicted Caption: a woman is holding a frisbee in the ocean
# BLEU-4 score: 40.42892997911646
# Real Caption: an equestrian fox [UNK] event is [UNK] in the rain.
# Predicted Caption: a woman is holding a frisbee in the ocean
# BLEU-4 score: 49.196255036686594
# Real Caption: a person with his hands up, riding a skateboard at a park.
# Predicted Caption: a woman is holding a frisbee in the ocean
# BLEU-4 score: 61.43868746168435
# Real Caption: a young kid having fun skateboarding down a side walk.
# Predicted Caption: a woman is holding a frisbee in the ocean
# BLEU-4 score: 68.65890479690393
# Real Caption: boy in white shirt and jeans riding a skateboard.
# Predicted Caption: a woman is holding a frisbee in the ocean
# BLEU-4 score: 73.0633242658635
# Real Caption: a boy that is riding a skateboard on the street.
# Predicted Caption: a woman is holding a frisbee in the ocean
# BLEU-4 score: 49.196255036686594
# Real Caption: a skateboarder appears to be [UNK] his balance skating down a sidewalk.
# Predicted Caption: a woman is holding a frisbee in the ocean
# BLEU-4 score: 43.668354428478125
# Real Caption: a street sign that reads [UNK] [UNK] on a country road.
# Predicted Caption: a woman is sitting on a bench next to a [UNK]
# BLEU-4 score: 12.358617564115113
# Real Caption: a street sign that says [UNK] [UNK] on it with a wood fence behind it and green grass and trees around the street next to it.
# Predicted Caption: a woman is sitting on a bench next to a [UNK]
# BLEU-4 score: 27.901593935858266
# Real Caption: the warning sign sits next to a concrete road.
# Predicted Caption: a woman is sitting on a bench next to a [UNK]
# BLEU-4 score: 34.85340766146352
# Real Caption: a fish eye lens takes a photo of a [UNK] roadway sign on a cloudy day.
# Predicted Caption: a woman is sitting on a bench next to a [UNK]
# BLEU-4 score: 33.529572102686124
# Real Caption: a [UNK] street and street sign depicting people holding hands and walking.
# Predicted Caption: a woman is sitting on a bench next to a [UNK]
# BLEU-4 score: 54.97775311418521
# Real Caption: a yellow fire truck driving through a busy traffic filled street.
# Predicted Caption: a man is holding a frisbee in the air
# BLEU-4 score: 49.196255036686594
# Real Caption: a yellow truck makes its way through an intersection in heavy traffic.
# Predicted Caption: a man is holding a frisbee in the air
# BLEU-4 score: 61.43868746168435
# Real Caption: a yellow [UNK] truck [UNK] the middle of an intersection.
# Predicted Caption: a man is holding a frisbee in the air
# BLEU-4 score: 68.65890479690393
# Real Caption: an [UNK] vehicle that is driving down the street.
# Predicted Caption: a man is holding a frisbee in the air
# BLEU-4 score: 39.39328149130935
# Real Caption: the traffic comes to a [UNK] as the fire engine proceeds across the intersection.
# Predicted Caption: a man is holding a frisbee in the air
# BLEU-4 score: 31.685654583328503
# Real Caption: a group of birds sitting on branches that are above water in a [UNK] drainage [UNK]
# Predicted Caption: a woman is sitting on a beach with a [UNK]
# BLEU-4 score: 66.96546139496112
# Real Caption: a group of geese sit on some shrubs in a river.
# Predicted Caption: a woman is sitting on a beach with a [UNK]
# BLEU-4 score: 56.23413251903491
# Real Caption: some birds that are standing on some debris in water.
# Predicted Caption: a woman is sitting on a beach with a [UNK]
# BLEU-4 score: 37.592003642100465
# Real Caption: a few birds sitting on tree branches and rocks in a waterway.
# Predicted Caption: a woman is sitting on a beach with a [UNK]
# BLEU-4 score: 56.23413251903491
# Real Caption: some black birds water and plants and a slope
# Predicted Caption: a woman is sitting on a beach with a [UNK]
# BLEU-4 score: 43.668354428478125
# Real Caption: a person water skiing falls in a lake.
# Predicted Caption: a person riding a wave on a surfboard in the ocean.
# BLEU-4 score: 43.668354428478125
# Real Caption: a surfer is covered in the spray from a large wave.
# Predicted Caption: a person riding a wave on a surfboard in the ocean.
# BLEU-4 score: 54.91004867761124
# Real Caption: the wake boarder has fallen off of the surfboard.
# Predicted Caption: a person riding a wave on a surfboard in the ocean.
# BLEU-4 score: 43.668354428478125
# Real Caption: a surfboard sitting in a large body of water.
# Predicted Caption: a person riding a wave on a surfboard in the ocean.
# BLEU-4 score: 72.26568811456053
# Real Caption: a body of water with a water ski sitting on top
# Predicted Caption: a person riding a wave on a surfboard in the ocean.
# BLEU-4 score: 48.54917717073234
# Real Caption: a man that has a hat with a cellphone.
# Predicted Caption: a man is riding a wave on a surfboard.
# BLEU-4 score: 32.3729563941832
# Real Caption: a man taking a photo with his cell phone in the mirror.
# Predicted Caption: a man is riding a wave on a surfboard.
# BLEU-4 score: 21.533650188818584
# Real Caption: a man is in a [UNK] pointing his [UNK] and is holding a cellphone.
# Predicted Caption: a man is riding a wave on a surfboard.
# BLEU-4 score: 40.42892997911646
# Real Caption: a man holding up a phone and pointing to it.
# Predicted Caption: a man is riding a wave on a surfboard.
# BLEU-4 score: 37.53119268751697
# Real Caption: a man is taking a picture in a mirror
# Predicted Caption: a man is riding a wave on a surfboard.
# BLEU-4 score: 38.60973950960897
# Real Caption: an entertainment center with a large screen television.
# Predicted Caption: a woman is sitting on a table with a [UNK]
# BLEU-4 score: 71.9590712857154
# Real Caption: a room that has a television on top of a dresser.
# Predicted Caption: a woman is sitting on a table with a [UNK]
# BLEU-4 score: 27.776190340117914
# Real Caption: a large television set is sitting on a dresser.
# Predicted Caption: a woman is sitting on a table with a [UNK]
# BLEU-4 score: 60.59285518620335
# Real Caption: a dresser covered in graffiti holding up a tv in a room.
# Predicted Caption: a woman is sitting on a table with a [UNK]
# BLEU-4 score: 42.728700639623405
# Real Caption: a dirty room filled with a dresser and tv set
# Predicted Caption: a woman is sitting on a table with a [UNK]
# BLEU-4 score: 57.735026918962575
# Real Caption: two food trucks are [UNK] spots near a sidewalk
# Predicted Caption: a man is holding a frisbee in the air
# BLEU-4 score: 61.43868746168435
# Real Caption: the truck is parked on the road and is yellow
# Predicted Caption: a man is holding a frisbee in the air
# BLEU-4 score: 68.65890479690393
# Real Caption: a yellow truck next to a [UNK] truck
# Predicted Caption: a man is holding a frisbee in the air
# BLEU-4 score: 46.230595512422084
# Real Caption: two trucks that are parked on the side of the street.
# Predicted Caption: a man is holding a frisbee in the air
# BLEU-4 score: 67.99308458396493
# Real Caption: a large truck on the side of a city street.
# Predicted Caption: a man is holding a frisbee in the air
# BLEU-4 score: 49.71247413297251
# Real Caption: a tan and green motorcycle grouped together with other motorcycles by a bike rack.
# Predicted Caption: a woman is sitting on a bench next to a [UNK]
# BLEU-4 score: 72.26568811456053
# Real Caption: a vintage green motorcycle is parked on the street.
# Predicted Caption: a woman is sitting on a bench next to a [UNK]
# BLEU-4 score: 54.91004867761124
# Real Caption: some people and a row of parked motorcycles
# Predicted Caption: a woman is sitting on a bench next to a [UNK]
# BLEU-4 score: 54.91004867761124
# Real Caption: an antique motorcycle sits parked at a show.
# Predicted Caption: a woman is sitting on a bench next to a [UNK]
# BLEU-4 score: 72.26568811456053
# Real Caption: a classic military motorcycle is parked in front of a crowd.
# Predicted Caption: a woman is sitting on a bench next to a [UNK]
# BLEU-4 score: 60.51012508914459
# Real Caption: a winter [UNK] of teddy bears eating at a [UNK] cafe
# Predicted Caption: a man is holding a red frisbee in the snow.
# BLEU-4 score: 41.659269994331375
# Real Caption: a large number of teddy bears are sitting at tables with fake food.
# Predicted Caption: a man is holding a red frisbee in the snow.
# BLEU-4 score: 60.51012508914459
# Real Caption: teddy bears and little animals are arranged in a tea party.
# Predicted Caption: a man is holding a red frisbee in the snow.
# BLEU-4 score: 46.04061366599648
# Real Caption: group of stuffed animals posed on furniture as if at a party.
# Predicted Caption: a man is holding a red frisbee in the snow.
# BLEU-4 score: 66.8740304976422
# Real Caption: a crowd of stuffed animals fill a room
# Predicted Caption: a man is holding a red frisbee in the snow.
# BLEU-4 score: 54.751825350694524
# Real Caption: two animals in a cage next to two people sitting in chairs.
# Predicted Caption: a black and white cat sitting on a city street.
# BLEU-4 score: 0
# Real Caption: some women are talking next to some sheep.
# Predicted Caption: a black and white cat sitting on a city street.
# BLEU-4 score: 66.8740304976422
# Real Caption: a herd of sheep standing inside of a pen.
# Predicted Caption: a black and white cat sitting on a city street.
# BLEU-4 score: 56.23413251903491
# Real Caption: two sheep in a pen near two [UNK]
# Predicted Caption: a black and white cat sitting on a city street.
# BLEU-4 score: 50.882747274015536
# Real Caption: spotted sheep are inside a pen while two women talk outside.
# Predicted Caption: a black and white cat sitting on a city street.
# BLEU-4 score: 77.65453555044466
# Real Caption: a water skier in a wet suit is doing a trick
# Predicted Caption: a man riding a wave on a surfboard in the ocean.
# BLEU-4 score: 54.91004867761124
# Real Caption: feet that are strapped onto a wake board.
# Predicted Caption: a man riding a wave on a surfboard in the ocean.
# BLEU-4 score: 36.72056269893593
# Real Caption: a man has his water board attached to his feet.
# Predicted Caption: a man riding a wave on a surfboard in the ocean.
# BLEU-4 score: 25.526076207555654
# Real Caption: a woman's legs are standing on a water ski as it glides in the ocean.
# Predicted Caption: a man riding a wave on a surfboard in the ocean.
# BLEU-4 score: 36.72056269893592
# Real Caption: a person on a surfboard in the water.
# Predicted Caption: a man riding a wave on a surfboard in the ocean.
# BLEU-4 score: 51.93071778680676
# Real Caption: a woman in an oriental dress on a cell phone.
# Predicted Caption: a woman is holding a tennis racquet on a tennis court.
# BLEU-4 score: 40.637982820134425
# Real Caption: a woman standing at a crosswalk using her cell phone.
# Predicted Caption: a woman is holding a tennis racquet on a tennis court.
# BLEU-4 score: 43.668354428478125
# Real Caption: a woman in a red kimono using a cell phone.
# Predicted Caption: a woman is holding a tennis racquet on a tennis court.
# BLEU-4 score: 36.40861793228486
# Real Caption: a woman in a red and white kimono facing a crowd of people.
# Predicted Caption: a woman is holding a tennis racquet on a tennis court.
# BLEU-4 score: 30.615876303600448
# Real Caption: a woman is sitting in a chair while talking on a cell phone.
# Predicted Caption: a woman is holding a tennis racquet on a tennis court.
# BLEU-4 score: 59.62494769762219
# Real Caption: a store with a worn down looking front and dirt parking lot.
# Predicted Caption: a woman is sitting on a bench next to a [UNK]
# BLEU-4 score: 0
# Real Caption: run down building with colorful signage but no people present
# Predicted Caption: a woman is sitting on a bench next to a [UNK]
# BLEU-4 score: 65.29942057256105
# Real Caption: the shops on the street are closed with steel [UNK]
# Predicted Caption: a woman is sitting on a bench next to a [UNK]
# BLEU-4 score: 65.29942057256105
# Real Caption: a rundown road is lined with closed shops.
# Predicted Caption: a woman is sitting on a bench next to a [UNK]
# BLEU-4 score: 54.91004867761124
# Real Caption: the [UNK] [UNK] stall has closed down .
# Predicted Caption: a woman is sitting on a bench next to a [UNK]
# BLEU-4 score: 66.96546139496112
# Real Caption: the snow boarder jumps over a larger tire on his snowboard.
# Predicted Caption: a woman is sitting on a surfboard in the ocean.
# BLEU-4 score: 48.549177170732335
# Real Caption: a person is flying through the air on a snowboard
# Predicted Caption: a woman is sitting on a surfboard in the ocean.
# BLEU-4 score: 14.901239998320879
# Real Caption: a man dressed in a coat and snow pants on a snowboard and doing a pose against a tire that is in the snow.
# Predicted Caption: a woman is sitting on a surfboard in the ocean.
# BLEU-4 score: 74.00828044922852
# Real Caption: snowboarder in mid air at a jump near a [UNK]
# Predicted Caption: a woman is sitting on a surfboard in the ocean.
# BLEU-4 score: 45.91497693322865
# Real Caption: a person jumping a snow board in the air
# Predicted Caption: a woman is sitting on a surfboard in the ocean.
# BLEU-4 score: 66.8740304976422
# Real Caption: a street sign hanging from a traffic light.
# Predicted Caption: a woman is sitting on a beach with a [UNK]
# BLEU-4 score: 41.545589177443254
# Real Caption: a street sign on a pole with stop lights on it
# Predicted Caption: a woman is sitting on a beach with a [UNK]
# BLEU-4 score: 42.728700639623405
# Real Caption: a street light with a hanging sign near trees.
# Predicted Caption: a woman is sitting on a beach with a [UNK]
# BLEU-4 score: 35.96611504718341
# Real Caption: there is a pole with two traffic lights and a [UNK] [UNK] sign.
# Predicted Caption: a woman is sitting on a beach with a [UNK]
# BLEU-4 score: 66.8740304976422
# Real Caption: the sign for [UNK] avenue is next to the stoplight.
# Predicted Caption: a woman is sitting on a beach with a [UNK]
# BLEU-4 score: 32.3729563941832
# Real Caption: a woman holding a wooden tray with mini pizzas sitting on it.
# Predicted Caption: a man is holding a frisbee in the air
# BLEU-4 score: 45.180100180492246
# Real Caption: two people holding a pizza near a table
# Predicted Caption: a man is holding a frisbee in the air
# BLEU-4 score: 57.735026918962575
# Real Caption: two women are serving pizzas on a platter.
# Predicted Caption: a man is holding a frisbee in the air
# BLEU-4 score: 0
# Real Caption: two young women about to serve hot pizza.
# Predicted Caption: a man is holding a frisbee in the air
# BLEU-4 score: 0
# Real Caption: four women and two are making some pizzas
# Predicted Caption: a man is holding a frisbee in the air
# BLEU-4 score: 56.23413251903491
# Real Caption: two people that are playing a frisbee game.
# Predicted Caption: a woman is holding a tennis racket in her hand.
# BLEU-4 score: 66.8740304976422
# Real Caption: two young people engaged in a frisbee competition.
# Predicted Caption: a woman is holding a tennis racket in her hand.
# BLEU-4 score: 42.728700639623405
# Real Caption: a woman tries to grab a frisbee from another woman.
# Predicted Caption: a woman is holding a tennis racket in her hand.
# BLEU-4 score: 66.8740304976422
# Real Caption: two girls fighting over a frisbee on a field
# Predicted Caption: a woman is holding a tennis racket in her hand.
# BLEU-4 score: 42.728700639623405
# Real Caption: a woman reaches to [UNK] a frisbee from an opponent.
# Predicted Caption: a woman is holding a tennis racket in her hand.
# BLEU-4 score: 74.00828044922852
# Real Caption: a giraffe munching on leaves with man standing in front.
# Predicted Caption: a woman is sitting on a beach with a [UNK]
# BLEU-4 score: 58.915104624545954
# Real Caption: a man stands next to a giraffe that is eating from a branch.
# Predicted Caption: a woman is sitting on a beach with a [UNK]
# BLEU-4 score: 66.8740304976422
# Real Caption: a man standing in front of a dead stuffed giraffe.
# Predicted Caption: a woman is sitting on a beach with a [UNK]
# BLEU-4 score: 58.915104624545954
# Real Caption: a man standing in front of a fake giraffe with its tongue [UNK]
# Predicted Caption: a woman is sitting on a beach with a [UNK]
# BLEU-4 score: 74.00828044922852
# Real Caption: a man poses by a statue of a giraffe.
# Predicted Caption: a woman is sitting on a beach with a [UNK]
# BLEU-4 score: 34.92059300639711
# Real Caption: a worn out teddy bear, left on the side of a road, and stuffing coming out of its foot.
# Predicted Caption: a woman is sitting on a table with her cell phone
# BLEU-4 score: 40.637982820134425
# Real Caption: [UNK] looking stuffed [UNK] sitting on the side of a road.
# Predicted Caption: a woman is sitting on a table with her cell phone
# BLEU-4 score: 41.88362313263686
# Real Caption: we are looking at a black and white photo of a stuffed animal setting on the ground.
# Predicted Caption: a woman is sitting on a table with her cell phone
# BLEU-4 score: 26.43191130222548
# Real Caption: a stuffed teddy bear is sitting on the sidewalk next to a street.
# Predicted Caption: a woman is sitting on a table with her cell phone
# BLEU-4 score: 72.26568811456053
# Real Caption: a car passing by a stuffed animal abandoned on the sidewalk.
# Predicted Caption: a woman is sitting on a table with her cell phone
# BLEU-4 score: 39.873605707511075
# Real Caption: a woman is standing on a tennis court swinging a tennis racket.
# Predicted Caption: a man riding a skateboard up a wave on a surfboard.
# BLEU-4 score: 43.668354428478125
# Real Caption: a woman on a court with a tennis racket.
# Predicted Caption: a man riding a skateboard up a wave on a surfboard.
# BLEU-4 score: 65.29942057256105
# Real Caption: a female tennis player [UNK] a tennis ball.
# Predicted Caption: a man riding a skateboard up a wave on a surfboard.
# BLEU-4 score: 65.29942057256105
# Real Caption: a woman playing tennis about to hit a tennis ball.
# Predicted Caption: a man riding a skateboard up a wave on a surfboard.
# BLEU-4 score: 43.668354428478125
# Real Caption: a woman is swinging at a tennis ball on a court.
# Predicted Caption: a man riding a skateboard up a wave on a surfboard.
# BLEU-4 score: 60.51012508914459
# Real Caption: many birds are perched on the weather vane of a building.
# Predicted Caption: a woman is sitting on a beach with a [UNK]
# BLEU-4 score: 66.8740304976422
# Real Caption: several birds perched on top of a weather vane.
# Predicted Caption: a woman is sitting on a beach with a [UNK]
# BLEU-4 score: 36.60109484748002
# Real Caption: many birds are sitting on the pole [UNK] at the top of a [UNK]
# Predicted Caption: a woman is sitting on a beach with a [UNK]
# BLEU-4 score: 66.8740304976422
# Real Caption: a group of birds resting on roof and weather vane.
# Predicted Caption: a woman is sitting on a beach with a [UNK]
# BLEU-4 score: 66.8740304976422
# Real Caption: the birds are sitting atop the flag on the tower.
# Predicted Caption: a woman is sitting on a beach with a [UNK]
# BLEU-4 score: 42.728700639623405
# Real Caption: a person jumping in the air with a frisbee
# Predicted Caption: a woman is sitting on a beach with a [UNK]
# BLEU-4 score: 56.23413251903491
# Real Caption: the man is playing frisbee in the field.
# Predicted Caption: a woman is sitting on a beach with a [UNK]
# BLEU-4 score: 36.75142442995998
# Real Caption: a man does a split in the air above some weeds as he catches a yellow frisbee.
# Predicted Caption: a woman is sitting on a beach with a [UNK]
# BLEU-4 score: 49.60923395774537
# Real Caption: a man with no shirt jumping up from high grass to catch a frisbee.
# Predicted Caption: a woman is sitting on a beach with a [UNK]
# BLEU-4 score: 42.728700639623405
# Real Caption: a man jumping in the air with a yellow frisbee.
# Predicted Caption: a woman is sitting on a beach with a [UNK]
# BLEU-4 score: 60.51012508914459
# Real Caption: a person wearing skis in the air above a snowy mountainside.
# Predicted Caption: a woman is sitting on a beach with a [UNK]
# BLEU-4 score: 42.728700639623405
# Real Caption: snowboarder jumping over a high run on a snowy mountainside.
# Predicted Caption: a woman is sitting on a beach with a [UNK]
# BLEU-4 score: 74.00828044922852
# Real Caption: a person that is jumping his snowboard on snow
# Predicted Caption: a woman is sitting on a beach with a [UNK]
# BLEU-4 score: 56.23413251903491
# Real Caption: a man flying through the air while riding skis.
# Predicted Caption: a woman is sitting on a beach with a [UNK]
# BLEU-4 score: 0
# Real Caption: the snowboarder has jumped very high into the air.
# Predicted Caption: a woman is sitting on a beach with a [UNK]
# BLEU-4 score: 41.8030412918096
# Real Caption: several people stand around a display of grapes and bananas at an outdoor market.
# Predicted Caption: a woman is sitting on a bench next to a [UNK]
# BLEU-4 score: 59.62494769762219
# Real Caption: a group of people standing around a man selling grapes and bananas.
# Predicted Caption: a woman is sitting on a bench next to a [UNK]
# BLEU-4 score: 65.29942057256105
# Real Caption: a group of people that are standing around boxes of [UNK]
# Predicted Caption: a woman is sitting on a bench next to a [UNK]
# BLEU-4 score: 0
# Real Caption: two women are buying fruit at an outdoor stand.
# Predicted Caption: a woman is sitting on a bench next to a [UNK]
# BLEU-4 score: 72.26568811456053
# Real Caption: a man is selling fruit from a stand.
# Predicted Caption: a woman is sitting on a bench next to a [UNK]
# BLEU-4 score: 61.43868746168435
# Real Caption: a person talking on a phone while wearing a [UNK]
# Predicted Caption: a man is holding a frisbee in the air
# BLEU-4 score: 43.443712531357924
# Real Caption: a man in a sweatshirt talking on a cell phone.
# Predicted Caption: a man is holding a frisbee in the air
# BLEU-4 score: 14.872972167876735
# Real Caption: a boy holding a cell phone up to his right ear and plugging his other ear with his [UNK]
# Predicted Caption: a man is holding a frisbee in the air
# BLEU-4 score: 48.7191740069029
# Real Caption: a person covers one ear while listening into a phone on the other.
# Predicted Caption: a man is holding a frisbee in the air
# BLEU-4 score: 46.230595512422084
# Real Caption: he plugged his ear with his finger to hear the [UNK]
# Predicted Caption: a man is holding a frisbee in the air
# BLEU-4 score: 36.17739608204856
# Real Caption: a man and a boy are looking at a birthday cake.
# Predicted Caption: a man is holding a frisbee in the air
# BLEU-4 score: 46.230595512422084
# Real Caption: there are two [UNK] that are looking at a birthday cake
# Predicted Caption: a man is holding a frisbee in the air
# BLEU-4 score: 68.65890479690393
# Real Caption: man and child observing a birthday cake with candles.
# Predicted Caption: a man is holding a frisbee in the air
# BLEU-4 score: 31.543673913721822
# Real Caption: a boy sits with his dad as he blows out the candles on his birthday cake.
# Predicted Caption: a man is holding a frisbee in the air
# BLEU-4 score: 43.443712531357924
# Real Caption: a man and child sit in front of a cake.
# Predicted Caption: a man is holding a frisbee in the air
# BLEU-4 score: 68.65890479690393
# Real Caption: a large gray elephant standing behind a wire fence.
# Predicted Caption: a woman is holding a frisbee in a park.
# BLEU-4 score: 57.735026918962575
# Real Caption: an elephant with tusks is standing between two [UNK]
# Predicted Caption: a woman is holding a frisbee in a park.
# BLEU-4 score: 57.735026918962575
# Real Caption: large elephant with tusks standing behind a metal fence.
# Predicted Caption: a woman is holding a frisbee in a park.
# BLEU-4 score: 0
# Real Caption: an elephant tries to reach food outside its bare paddock.
# Predicted Caption: a woman is holding a frisbee in a park.
# BLEU-4 score: 45.180100180492246
# Real Caption: a large elephant standing in a fenced enclosure.
# Predicted Caption: a woman is holding a frisbee in a park.
# BLEU-4 score: 66.8740304976422
# Real Caption: a double decker bus pulled off on a paved street.
# Predicted Caption: a woman is holding a tennis racket in her mouth.
# BLEU-4 score: 66.8740304976422
# Real Caption: a double decker bus runs on a city street.
# Predicted Caption: a woman is holding a tennis racket in her mouth.
# BLEU-4 score: 56.23413251903491
# Real Caption: a double-decker bus parked on the side of the road.
# Predicted Caption: a woman is holding a tennis racket in her mouth.
# BLEU-4 score: 66.8740304976422
# Real Caption: a red two story bus on a city street.
# Predicted Caption: a woman is holding a tennis racket in her mouth.
# BLEU-4 score: 66.8740304976422
# Real Caption: a double decker red bus is going through the city.
# Predicted Caption: a woman is holding a tennis racket in her mouth.
# BLEU-4 score: 72.26568811456053
# Real Caption: a semi for staples with a broken end to it
# Predicted Caption: a woman is sitting on a table with her cell phone
# BLEU-4 score: 65.29942057256105
# Real Caption: a delivery truck driving along side a larger truck.
# Predicted Caption: a woman is sitting on a table with her cell phone
# BLEU-4 score: 54.91004867761124
# Real Caption: a damaged staples delivery truck has had the back ripped open.
# Predicted Caption: a woman is sitting on a table with her cell phone
# BLEU-4 score: 38.49742634318483
# Real Caption: a truck that is sitting in a parking lot with the back open.
# Predicted Caption: a woman is sitting on a table with her cell phone
# BLEU-4 score: 49.71247413297251
# Real Caption: a box truck with the cargo door frame partly ripped off by an accident.
# Predicted Caption: a woman is sitting on a table with her cell phone
# BLEU-4 score: 65.29942057256105
# Real Caption: a man behind a bunch of oranges for sale
# Predicted Caption: a woman is holding a tennis racquet on a tennis court.
# BLEU-4 score: 65.29942057256105
# Real Caption: a man standing in front of a bunch of oranges
# Predicted Caption: a woman is holding a tennis racquet on a tennis court.
# BLEU-4 score: 65.29942057256105
# Real Caption: a young man is standing around by oranges
# Predicted Caption: a woman is holding a tennis racquet on a tennis court.
# BLEU-4 score: 65.29942057256105
# Real Caption: a man looking at a container filled with oranges.
# Predicted Caption: a woman is holding a tennis racquet on a tennis court.
# BLEU-4 score: 65.29942057256105
# Real Caption: a man sells oranges at a [UNK] [UNK]
# Predicted Caption: a woman is holding a tennis racquet on a tennis court.
# BLEU-4 score: 59.62494769762219
# Real Caption: a group of people standing around with a kid and two [UNK]
# Predicted Caption: a man riding a wave on a surfboard in the ocean.
# BLEU-4 score: 40.637982820134425
# Real Caption: a bunch of people skiing in the snow.
# Predicted Caption: a man riding a wave on a surfboard in the ocean.
# BLEU-4 score: 40.637982820134425
# Real Caption: a group of people some one ski's in the snow .
# Predicted Caption: a man riding a wave on a surfboard in the ocean.
# BLEU-4 score: 36.72056269893593
# Real Caption: men, woman, and children standing in the snow.
# Predicted Caption: a man riding a wave on a surfboard in the ocean.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-64-83bac2c66687> in <module>()
#       1 bleu_scores = []
#       2 for i in range(len(img_name_test)):
# ----> 3   bleu_score = test_single_img(i)
#       4   bleu_scores.append(bleu_score)
#       5
#
# <ipython-input-62-c00bf07aa312> in test_single_img(id)
#       7   # for caption in captions:
#       8   real_caption = ' '.join([tf.compat.as_text(index_to_word(i).numpy()) for i in caption if i not in [0]])
# ----> 9   caption, result = evaluate(image)
#      10
#      11   first = real_caption.split(' ', 1)[1]
#
# <ipython-input-61-6d82563761a6> in evaluate(image)
#      11
#      12    for i in range(100):
# ---> 13       features = encoder(img_tensor_val)
#      14       predictions = decoder(output, features)
#      15
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1094         with autocast_variable.enable_auto_cast_variables(
#    1095             self._compute_dtype_object):
# -> 1096           outputs = call_fn(inputs, *args, **kwargs)
#    1097
#    1098         if self._activity_regularizer:
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      90     bound_signature = None
#      91     try:
# ---> 92       return fn(*args, **kwargs)
#      93     except Exception as e:  # pylint: disable=broad-except
#      94       if hasattr(e, '_keras_call_info_injected'):
#
# <ipython-input-46-3980922be9ee> in call(self, x, is_training)
#      41
#      42         gmlp_layers = self.gmlp_layers if not is_training else dropout_layers(self.gmlp_layers, self.prob_survival)
# ---> 43         x = tf.keras.Sequential(gmlp_layers)(x)
#      44         return self.to_logits(x)
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py in __call__(self, *args, **kwargs)
#    1094         with autocast_variable.enable_auto_cast_variables(
#    1095             self._compute_dtype_object):
# -> 1096           outputs = call_fn(inputs, *args, **kwargs)
#    1097
#    1098         if self._activity_regularizer:
#
# /usr/local/lib/python3.7/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      90     bound_signature = None
#      91     try:
# ---> 92       return fn(*args, **kwargs)
#      93     except Exception as e:  # pylint: disable=broad-except
#      94       if hasattr(e, '_keras_call_info_injected'):
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py in call(self, inputs, training, mask)
#     367                           'API.')
#     368       else:
# --> 369         self._build_graph_network_for_inferred_shape(inputs.shape, inputs.dtype)
#     370
#     371     if self._graph_initialized:
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/training/tracking/base.py in _method_wrapper(self, *args, **kwargs)
#     627     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     628     try:
# --> 629       result = method(self, *args, **kwargs)
#     630     finally:
#     631       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py in _build_graph_network_for_inferred_shape(self, input_shape, input_dtype)
#     296             # technically illegal as per the `add()` docstring,
#     297             # but wasn't previously disabled).
# --> 298             clear_previously_created_nodes(layer, self._created_nodes)
#     299             try:
#     300               # Create Functional API connection by calling the current layer
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/sequential.py in clear_previously_created_nodes(layer, created_nodes)
#     495   """Remove nodes from `created_nodes` from the layer's inbound_nodes."""
#     496   for node in layer._inbound_nodes:
# --> 497     prev_layers = node.inbound_layers
#     498     for prev_layer in tf.nest.flatten(prev_layers):
#     499       prev_layer._outbound_nodes = [
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/node.py in inbound_layers(self)
#     270       return []
#     271     inbound_layers = tf.nest.map_structure(lambda t: t._keras_history.layer,
# --> 272                                         self.call_args[0])
#     273     return inbound_layers
#     274
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/util/nest.py in map_structure(func, *structure, **kwargs)
#     904         "`expand_composites`, not: `%s`" % ("`, `".join(kwargs.keys())))
#     905
# --> 906   for other in structure[1:]:
#     907     assert_same_structure(structure[0], other, check_types=check_types,
#     908                           expand_composites=expand_composites)
#
# KeyboardInterrupt:
