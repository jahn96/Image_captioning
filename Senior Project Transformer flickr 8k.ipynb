# %% [markdown]
# ##### Copyright 2018 The TensorFlow Authors.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf

# You'll generate plots of attention in order to see which parts of an image
# your model focuses on during captioning
import matplotlib.pyplot as plt

import collections
import random
import numpy as np
import os
import time
import json
from tensorflow import keras
from PIL import Image
from tensorflow.keras import layers
from tensorflow.keras.applications import efficientnet
from tensorflow.keras.layers import TextVectorization

# %%
import os
import re
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.applications import efficientnet
from tensorflow.keras.layers import TextVectorization
from PIL import Image
import time

seed = 111
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
# !wget -q https://github.com/jbrownlee/Datasets/releases/download/Flickr8k/Flickr8k_Dataset.zip
# !wget -q https://github.com/jbrownlee/Datasets/releases/download/Flickr8k/Flickr8k_text.zip
# !unzip -qq Flickr8k_Dataset.zip
# !unzip -qq Flickr8k_text.zip
# !rm Flickr8k_Dataset.zip Flickr8k_text.zip

# %%
# Path to the images
IMAGES_PATH = "Flicker8k_Dataset"

# Desired image dimensions
IMAGE_SIZE = (299, 299)

# Vocabulary size
VOCAB_SIZE = 5000 # 10000

# Fixed length allowed for any sequence
SEQ_LENGTH = 50 # 25

# Dimension for the image embeddings and token embeddings
EMBED_DIM = 512

# Other training parameters
BATCH_SIZE = 64
EPOCHS = 30
AUTOTUNE = tf.data.AUTOTUNE

# %%
def load_captions_data(filename):
    """Loads captions (text) data and maps them to corresponding images.

    Args:
        filename: Path to the text file containing caption data.

    Returns:
        caption_mapping: Dictionary mapping image names and the corresponding captions
        text_data: List containing all the available captions
    """

    with open(filename) as caption_file:
        caption_data = caption_file.readlines()
        caption_mapping = {}
        text_data = []
        images_to_skip = set()

        for line in caption_data:
            line = line.rstrip("\n")
            # Image name and captions are separated using a tab
            img_name, caption = line.split("\t")

            # Each image is repeated five times for the five different captions.
            # Each image name has a suffix `#(caption_number)`
            img_name = img_name.split("#")[0]
            img_name = os.path.join(IMAGES_PATH, img_name.strip())

            # We will remove caption that are either too short to too long
            tokens = caption.strip().split()

            if len(tokens) < 5 or len(tokens) > SEQ_LENGTH:
                images_to_skip.add(img_name)
                continue

            if img_name.endswith("jpg") and img_name not in images_to_skip:
                # We will add a start and an end token to each caption
                caption = "<start> " + caption.strip() + " <end>"
                text_data.append(caption)

                if img_name in caption_mapping:
                    caption_mapping[img_name].append(caption)
                else:
                    caption_mapping[img_name] = [caption]

        for img_name in images_to_skip:
            if img_name in caption_mapping:
                del caption_mapping[img_name]

        return caption_mapping, text_data


def train_val_split(caption_data, train_valid_split=0.6, shuffle=True):
    """Split the captioning dataset into train and validation sets.

    Args:
        caption_data (dict): Dictionary containing the mapped caption data
        train_valid_split (float): Fraction of all the full dataset to use as training data
        shuffle (bool): Whether to shuffle the dataset before splitting

    Returns:
        Traning and validation datasets as two separated dicts
    """

    # 1. Get the list of all image names
    all_images = list(caption_data.keys())

    # 2. Shuffle if necessary
    if shuffle:
        np.random.shuffle(all_images)

    # 3. Split into training and validation sets
    train_size = int(len(caption_data) * train_valid_split)

    # 4. Split into validation and testing sets
    valid_size = int(len(caption_data) * (1 - train_valid_split) / 2)

    training_data = {
        img_name: caption_data[img_name] for img_name in all_images[:train_size]
    }
    validation_data = {
        img_name: caption_data[img_name] for img_name in all_images[train_size: train_size + valid_size]
    }

    testing_data = {
        img_name: caption_data[img_name] for img_name in all_images[train_size + valid_size:]
    }

    # 4. Return the splits
    return training_data, validation_data, testing_data


# Load the dataset
captions_mapping, text_data = load_captions_data("Flickr8k.token.txt")

# Split the dataset into training and validation sets
train_data, valid_data, testing_data = train_val_split(captions_mapping)
print("Number of training samples: ", len(train_data))
print("Number of validation samples: ", len(valid_data))
print("Number of testing samples: ", len(testing_data))
# Out:
# Number of training samples:  4680
# Number of validation samples:  1560
# Number of testing samples:  1561

# %%
# load image
import random

images = list(train_data.keys())
img_path = images[random.randint(0, len(images))]
Image.open(img_path)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x500 at 0x7F97508D5C50>

# %%
train_data[img_path]
# Out:
# ['<start> A brown dog digging for a ball in the sand <end>',
#  '<start> A brown dog digs in the sand for an orange ball . <end>',
#  '<start> A brown dog is trying to retrive his orange ball that has fallen in a dirt hole . <end>',
#  '<start> A dog burrowing in the dirt trying to get an orange ball . <end>',
#  '<start> A dog digging for his ball in the sand . <end>']

# %%
def custom_standardization(input_string):
    lowercase = tf.strings.lower(input_string)
    return tf.strings.regex_replace(lowercase, "[%s]" % re.escape(strip_chars), "")


strip_chars = "!\"#$%&'()*+,-./:;<=>?@[\]^_`{|}~"
strip_chars = strip_chars.replace("<", "")
strip_chars = strip_chars.replace(">", "")

vectorization = TextVectorization(
    max_tokens=VOCAB_SIZE,
    output_mode="int",
    output_sequence_length=SEQ_LENGTH,
    standardize=custom_standardization,
)
vectorization.adapt(text_data)

# Data augmentation for image data
# image_augmentation = keras.Sequential(
#     [
#         layers.RandomFlip("horizontal"),
#         layers.RandomRotation(0.2),
#         layers.RandomContrast(0.3),
#     ]
# )

# %%
# Create mappings for words to indices and indicies to words.
word_to_index = tf.keras.layers.StringLookup(
    mask_token="",
    vocabulary=vectorization.get_vocabulary())
index_to_word = tf.keras.layers.StringLookup(
    mask_token="",
    vocabulary=vectorization.get_vocabulary(),
    invert=True)

# %%
def decode_and_resize(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, IMAGE_SIZE)
    img = tf.image.convert_image_dtype(img, tf.float32)
    img = tf.keras.applications.inception_v3.preprocess_input(img)
    return img


def process_input(img_path, captions):
    return decode_and_resize(img_path), vectorization(captions)


def make_dataset(images, captions):
    dataset = tf.data.Dataset.from_tensor_slices((images, captions))
    dataset = dataset.shuffle(len(images))
    dataset = dataset.map(process_input, num_parallel_calls=AUTOTUNE)
    dataset = dataset.batch(BATCH_SIZE).prefetch(AUTOTUNE)

    return dataset


# Pass the list of images and the list of corresponding captions
train_dataset = make_dataset(list(train_data.keys()), list(train_data.values()))

valid_dataset = make_dataset(list(valid_data.keys()), list(valid_data.values()))

test_dataset = make_dataset(list(testing_data.keys()), list(testing_data.values()))

# %%
train_dataset
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 299, 299, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, None, 50), dtype=tf.int64, name=None))>

# %%
valid_dataset
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 299, 299, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, None, 50), dtype=tf.int64, name=None))>

# %%
test_dataset
# Out:
# <PrefetchDataset element_spec=(TensorSpec(shape=(None, 299, 299, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, None, 50), dtype=tf.int64, name=None))>

# %% [markdown]
# ## InceptionV3 as Encoder

# %%
def get_cnn_model():
    image_model = tf.keras.applications.InceptionV3(include_top=False,
                                                weights='imagenet')
    # We freeze our feature extractor
    image_model.trainable = False
    base_model_out = image_model.output
    base_model_out = layers.Reshape((-1, base_model_out.shape[-1]))(base_model_out)
    cnn_model = keras.models.Model(image_model.input, base_model_out)
    return cnn_model

# %% [markdown]
# Positional Encoding

# %%
def get_angles(pos, i, d_model):
   angle_rates = 1 / np.power(10000, (2 * (i//2)) / np.float32(d_model))
   return pos * angle_rates

def positional_encoding_1d(position, d_model):
   angle_rads = get_angles(np.arange(position)[:, np.newaxis],
                           np.arange(d_model)[np.newaxis, :],
                           d_model)

   angle_rads[:, 0::2] = np.sin(angle_rads[:, 0::2])
   angle_rads[:, 1::2] = np.cos(angle_rads[:, 1::2])
   pos_encoding = angle_rads[np.newaxis, ...]
   return tf.cast(pos_encoding, dtype=tf.float32)

def positional_encoding_2d(row,col,d_model):
   assert d_model % 2 == 0
   row_pos = np.repeat(np.arange(row),col)[:,np.newaxis]
   col_pos = np.repeat(np.expand_dims(np.arange(col),0),row,axis=0).reshape(-1,1)

   angle_rads_row = get_angles(row_pos,np.arange(d_model//2)[np.newaxis,:],d_model//2)
   angle_rads_col = get_angles(col_pos,np.arange(d_model//2)[np.newaxis,:],d_model//2)

   angle_rads_row[:, 0::2] = np.sin(angle_rads_row[:, 0::2])
   angle_rads_row[:, 1::2] = np.cos(angle_rads_row[:, 1::2])
   angle_rads_col[:, 0::2] = np.sin(angle_rads_col[:, 0::2])
   angle_rads_col[:, 1::2] = np.cos(angle_rads_col[:, 1::2])
   pos_encoding = np.concatenate([angle_rads_row,angle_rads_col],axis=1)[np.newaxis, ...]
   return tf.cast(pos_encoding, dtype=tf.float32)

# %% [markdown]
# ## Model
#
# Fun fact: the decoder below is identical to the one in the example for [Neural Machine Translation with Attention](https://www.tensorflow.org/text/tutorials/nmt_with_attention).
#
# The model architecture is inspired by the [Show, Attend and Tell](https://arxiv.org/pdf/1502.03044.pdf) paper.
#
# * In this example, you extract the features from the lower convolutional layer of InceptionV3 giving us a vector of shape (8, 8, 2048).
# * You squash that to a shape of (64, 2048).
# * This vector is then passed through the CNN Encoder (which consists of a single Fully connected layer).
# * The RNN (here GRU) attends over the image to predict the next word.

# %%
def create_padding_mask(seq):
   seq = tf.cast(tf.math.equal(seq, 0), tf.float32)
   return seq[:, tf.newaxis, tf.newaxis, :]  # (batch_size, 1, 1, seq_len)

def create_look_ahead_mask(size):
   mask = 1 - tf.linalg.band_part(tf.ones((size, size)), -1, 0)
   return mask  # (seq_len, seq_len)

def scaled_dot_product_attention(q, k, v, mask):
   matmul_qk = tf.matmul(q, k, transpose_b=True)  # (..., seq_len_q, seq_len_k)
   dk = tf.cast(tf.shape(k)[-1], tf.float32)
   scaled_attention_logits = matmul_qk / tf.math.sqrt(dk)

   if mask is not None:
      scaled_attention_logits += (mask * -1e9) 

   attention_weights = tf.nn.softmax(scaled_attention_logits, axis=-1) 
   output = tf.matmul(attention_weights, v)  # (..., seq_len_q, depth_v)

   return output, attention_weights

class MultiHeadAttention(tf.keras.layers.Layer):
   def __init__(self, d_model, num_heads):
      super(MultiHeadAttention, self).__init__()
      self.num_heads = num_heads
      self.d_model = d_model
      assert d_model % self.num_heads == 0
      self.depth = d_model // self.num_heads
      self.wq = tf.keras.layers.Dense(d_model)
      self.wk = tf.keras.layers.Dense(d_model)
      self.wv = tf.keras.layers.Dense(d_model)
      self.dense = tf.keras.layers.Dense(d_model)

   def split_heads(self, x, batch_size):
      x = tf.reshape(x, (batch_size, -1, self.num_heads, self.depth))
      return tf.transpose(x, perm=[0, 2, 1, 3])

   def call(self, v, k, q, mask=None):
      batch_size = tf.shape(q)[0]
      q = self.wq(q)  # (batch_size, seq_len, d_model)
      k = self.wk(k)  # (batch_size, seq_len, d_model)
      v = self.wv(v)  # (batch_size, seq_len, d_model)

      q = self.split_heads(q, batch_size)  # (batch_size, num_heads, seq_len_q, depth)
      k = self.split_heads(k, batch_size)  # (batch_size, num_heads, seq_len_k, depth)
      v = self.split_heads(v, batch_size)  # (batch_size, num_heads, seq_len_v, depth)

      scaled_attention, attention_weights = scaled_dot_product_attention(q, k, v, mask)
      scaled_attention = tf.transpose(scaled_attention, perm=[0, 2, 1, 3])  # (batch_size, seq_len_q,      num_heads, depth)

      concat_attention = tf.reshape(scaled_attention,
                                 (batch_size, -1, self.d_model))  # (batch_size, seq_len_q, d_model)

      output = self.dense(concat_attention)  # (batch_size, seq_len_q, d_model)
      return output, attention_weights

def point_wise_feed_forward_network(d_model, dff):
   return tf.keras.Sequential([
                tf.keras.layers.Dense(dff, activation='relu'),  # (batch_size, seq_len, dff)
                tf.keras.layers.Dense(d_model)])  # (batch_size, seq_len, d_model)])

# %% [markdown]
# Encoder-Decoder Layer

# %%
class EncoderLayer(tf.keras.layers.Layer):
   def __init__(self, d_model, num_heads, dff, rate=0.1):
      super(EncoderLayer, self).__init__()
      self.mha = MultiHeadAttention(d_model, num_heads)
      self.ffn = point_wise_feed_forward_network(d_model, dff)

      self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
      self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

      self.dropout1 = tf.keras.layers.Dropout(rate)
      self.dropout2 = tf.keras.layers.Dropout(rate)


   def call(self, x, training, mask=None):
      attn_output, _ = self.mha(x, x, x, mask)  # (batch_size, input_seq_len, d_model)
      attn_output = self.dropout1(attn_output, training=training)
      out1 = self.layernorm1(x + attn_output)  # (batch_size, input_seq_len, d_model)

      ffn_output = self.ffn(out1)  # (batch_size, input_seq_len, d_model)
      ffn_output = self.dropout2(ffn_output, training=training)
      out2 = self.layernorm2(out1 + ffn_output)  # (batch_size, input_seq_len, d_model)
      return out2

class DecoderLayer(tf.keras.layers.Layer):
   def __init__(self, d_model, num_heads, dff, rate=0.1):
      super(DecoderLayer, self).__init__()
      self.mha1 = MultiHeadAttention(d_model, num_heads)
      self.mha2 = MultiHeadAttention(d_model, num_heads)

      self.ffn = point_wise_feed_forward_network(d_model, dff)

      self.layernorm1 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
      self.layernorm2 = tf.keras.layers.LayerNormalization(epsilon=1e-6)
      self.layernorm3 = tf.keras.layers.LayerNormalization(epsilon=1e-6)

      self.dropout1 = tf.keras.layers.Dropout(rate)
      self.dropout2 = tf.keras.layers.Dropout(rate)
      self.dropout3 = tf.keras.layers.Dropout(rate)

   def call(self, x, enc_output, training,look_ahead_mask=None, padding_mask=None):
      attn1, attn_weights_block1 = self.mha1(x, x, x, look_ahead_mask)  # (batch_size, target_seq_len, d_model)
      attn1 = self.dropout1(attn1, training=training)
      out1 = self.layernorm1(attn1 + x)

      attn2, attn_weights_block2 = self.mha2(enc_output, enc_output, out1, padding_mask) 
      attn2 = self.dropout2(attn2, training=training)
      out2 = self.layernorm2(attn2 + out1)  # (batch_size, target_seq_len, d_model)

      ffn_output = self.ffn(out2)  # (batch_size, target_seq_len, d_model)
      ffn_output = self.dropout3(ffn_output, training=training)
      out3 = self.layernorm3(ffn_output + out2)  # (batch_size, target_seq_len, d_model)

      return out3, attn_weights_block1, attn_weights_block2

class Encoder(tf.keras.layers.Layer):
   def __init__(self, num_layers, d_model, num_heads, dff, row_size,col_size,rate=0.1):
      super(Encoder, self).__init__()
      self.d_model = d_model
      self.num_layers = num_layers

      self.embedding = tf.keras.layers.Dense(self.d_model,activation='relu')
      self.pos_encoding = positional_encoding_2d(row_size,col_size,self.d_model)

      self.enc_layers = [EncoderLayer(d_model, num_heads, dff, rate) for _ in range(num_layers)]
      self.dropout = tf.keras.layers.Dropout(rate)

   def call(self, x, training, mask=None):
      seq_len = tf.shape(x)[1]
      x = self.embedding(x)  # (batch_size, input_seq_len(H*W), d_model)
      x += self.pos_encoding[:, :seq_len, :]
      x = self.dropout(x, training=training)

      for i in range(self.num_layers):
         x = self.enc_layers[i](x, training, mask)

      return x  # (batch_size, input_seq_len, d_model)

class Decoder(tf.keras.layers.Layer):
   def __init__(self, num_layers,d_model,num_heads,dff, target_vocab_size, maximum_position_encoding,   rate=0.1):
      super(Decoder, self).__init__()
      self.d_model = d_model
      self.num_layers = num_layers

      self.embedding = tf.keras.layers.Embedding(target_vocab_size, d_model)
      self.pos_encoding = positional_encoding_1d(maximum_position_encoding, d_model)

      self.dec_layers = [DecoderLayer(d_model, num_heads, dff, rate)
                         for _ in range(num_layers)]
      self.dropout = tf.keras.layers.Dropout(rate)

   def call(self, x, enc_output, training,look_ahead_mask=None, padding_mask=None):
      seq_len = tf.shape(x)[1]
      attention_weights = {}

      x = self.embedding(x)  # (batch_size, target_seq_len, d_model)
      x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
      x += self.pos_encoding[:, :seq_len, :]
      x = self.dropout(x, training=training)

      for i in range(self.num_layers):
         x, block1, block2 = self.dec_layers[i](x, enc_output, training,
                                            look_ahead_mask, padding_mask)
         
         attention_weights['decoder_layer{}_block1'.format(i+1)] = block1
         attention_weights['decoder_layer{}_block2'.format(i+1)] = block2

      return x, attention_weights

# %% [markdown]
# Transformer

# %%
class Transformer(tf.keras.Model):
   def __init__(self, num_layers, d_model, num_heads, dff,row_size,col_size,
              target_vocab_size,max_pos_encoding, rate=0.1):
      super(Transformer, self).__init__()
      self.encoder = Encoder(num_layers, d_model, num_heads, dff,row_size,col_size, rate)
      self.decoder = Decoder(num_layers, d_model, num_heads, dff,
                          target_vocab_size,max_pos_encoding, rate)
      self.final_layer = tf.keras.layers.Dense(target_vocab_size)

   def call(self, inp, tar, training,look_ahead_mask=None,dec_padding_mask=None,enc_padding_mask=None   ):
      enc_output = self.encoder(inp, training, enc_padding_mask)  # (batch_size, inp_seq_len, d_model      )
      dec_output, attention_weights = self.decoder(
      tar, enc_output, training, look_ahead_mask, dec_padding_mask)
      final_output = self.final_layer(dec_output)  # (batch_size, tar_seq_len, target_vocab_size)
      return final_output, attention_weights

# %% [markdown]
# Model Hyperparameters

# %%
num_layer = 1
d_model = 512
dff = 2048
num_heads = 8
row_size = 8
col_size = 8
target_vocab_size = VOCAB_SIZE + 1
dropout_rate = 0.1

# %%
class CustomSchedule(tf.keras.optimizers.schedules.LearningRateSchedule):
   def __init__(self, d_model, warmup_steps=4000):
      super(CustomSchedule, self).__init__()
      self.d_model = d_model
      self.d_model = tf.cast(self.d_model, tf.float32)
      self.warmup_steps = warmup_steps

   def __call__(self, step):
      arg1 = tf.math.rsqrt(step)
      arg2 = step * (self.warmup_steps ** -1.5)
      return tf.math.rsqrt(self.d_model) * tf.math.minimum(arg1, arg2)

# %%
learning_rate = CustomSchedule(d_model)
optimizer = tf.keras.optimizers.Adam(learning_rate, beta_1=0.9, beta_2=0.98,
                                    epsilon=1e-9)
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')

def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)
    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask
    return tf.reduce_sum(loss_)/tf.reduce_sum(mask)

train_loss = tf.keras.metrics.Mean(name='train_loss')
train_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='train_accuracy')

val_loss = tf.keras.metrics.Mean(name='val_loss')
val_accuracy = tf.keras.metrics.SparseCategoricalAccuracy(name='val_accuracy')

cnn_model = get_cnn_model()
transformer = Transformer(num_layer,d_model,num_heads,dff,row_size,col_size,target_vocab_size, max_pos_encoding=target_vocab_size,rate=dropout_rate)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 0s 0us/step
# 87924736/87910968 [==============================] - 0s 0us/step

# %% [markdown]
# Checkpoint

# %%
# checkpoint_path = "./checkpoints/train"
checkpoint_path = '/content/drive/MyDrive/My Senior Project Spring 2022/checkpoint/Transformer_flicker8k'
ckpt = tf.train.Checkpoint(transformer=transformer,
                           optimizer=optimizer)
ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=1)

start_epoch = 0
if ckpt_manager.latest_checkpoint:
  start_epoch = int(ckpt_manager.latest_checkpoint.split('-')[-1])
  # restoring the latest checkpoint in checkpoint_path
  ckpt.restore(ckpt_manager.latest_checkpoint)

# %%
print(start_epoch)
# Out:
# 0

# %%
f0 = open("/content/drive/MyDrive/My Senior Project Spring 2022/checkpoint/Transformer/train_losses.txt", "w")
f1 = open("/content/drive/MyDrive/My Senior Project Spring 2022/checkpoint/Transformer/train_accuracies.txt", "w")
f2 = open("/content/drive/MyDrive/My Senior Project Spring 2022/checkpoint/Transformer/val_losses.txt", "w")
f3 = open("/content/drive/MyDrive/My Senior Project Spring 2022/checkpoint/Transformer/val_accuracies.txt", "w")

# %% [markdown]
# Model Training

# %%
def create_masks_decoder(tar):
   look_ahead_mask = create_look_ahead_mask(tf.shape(tar)[1])
   dec_target_padding_mask = create_padding_mask(tar)
   combined_mask = tf.maximum(dec_target_padding_mask, look_ahead_mask)
   return combined_mask

def train_step(img_tensor, tar, is_training):
    # 1. Get image embeddings
    img_tensor = cnn_model(img_tensor)

    # 2. Pass each of the five captions one by one to the decoder
    # along with the encoder outputs and compute the loss as well as accuracy
    # for each caption.
    # num_captions_per_image = 5
    all_captions_loss = 0
    for i in range(5):
        tar_inp = tar[:, i, :-1]
        tar_real = tar[:, i, 1:]
        dec_mask = create_masks_decoder(tar_inp)

        if is_training:
            with tf.GradientTape() as tape:
                predictions, _ = transformer(img_tensor, tar_inp, True, dec_mask)
                loss = loss_function(tar_real, predictions)
                all_captions_loss += loss

                gradients = tape.gradient(loss, transformer.trainable_variables)   
                optimizer.apply_gradients(zip(gradients, transformer.trainable_variables))
        
                train_loss(loss)
                train_accuracy(tar_real, predictions)
        else:
            predictions, _ = transformer(img_tensor, tar_inp, False, dec_mask)
            loss = loss_function(tar_real, predictions)

            val_loss(loss)
            val_accuracy(tar_real, predictions)

# %%
train_losses = []
train_accuracies = []

val_losses = []
val_accuracies = []

for epoch in range(start_epoch, 21):
   start = time.time()
   train_loss.reset_states()
   train_accuracy.reset_states()
   for (batch, (img_tensor, tar)) in enumerate(train_dataset):
      train_step(img_tensor, tar, True)
      if batch % 50 == 0:
         print ('Epoch {} Batch {} Loss {:.4f} Accuracy {:.4f}'.format(
         epoch + 1, batch, train_loss.result(), train_accuracy.result()))

   train_losses.append(train_loss.result() / 5)
   train_accuracies.append(train_accuracy.result() / 5)
   f0.write(str(train_loss.result().numpy()))
   f1.write(str(train_accuracy.result().numpy()))



   # validation
   val_loss.reset_states()
   val_accuracy.reset_states()
   for (batch, (img_tensor, tar)) in enumerate(valid_dataset):
     train_step(img_tensor, tar, False)
     if batch % 50 == 0:
         print ('Epoch {} Batch {} Validation Loss {:.4f} Validation Accuracy {:.4f}'.format(
         epoch + 1, batch, val_loss.result(), val_accuracy.result()))

   val_losses.append(val_loss.result() / 5)
   val_accuracies.append(val_accuracy.result() / 5)

   f2.write(str(val_loss.result().numpy()))
   f3.write(str(val_accuracy.result().numpy()))

   if epoch % 10 == 0:
      ckpt_manager.save(checkpoint_number=epoch)     

   print ('Epoch {} Loss {:.4f} Accuracy {:.4f}'.format(epoch + 1,
                                               train_loss.result(),
                                               train_accuracy.result()))
   
   print ('Epoch {} Validation Loss {:.4f} Validation Accuracy {:.4f}'.format(epoch + 1,
                                               val_loss.result(),
                                               val_accuracy.result()))
   
   print ('Time taken for 1 epoch: {} secs\n'.format(time.time() - start))

f0.close()
f1.close()
f2.close()
f3.close()
# Out:
# Epoch 1 Batch 0 Loss 8.7200 Accuracy 0.0001
# Epoch 1 Batch 50 Loss 6.7177 Accuracy 0.0335
# Epoch 1 Batch 0 Validation Loss 4.4931 Validation Accuracy 0.0676
# Epoch 1 Loss 6.1233 Accuracy 0.0417
# Epoch 1 Validation Loss 4.4723 Validation Accuracy 0.0671
# Time taken for 1 epoch: 72.23871636390686 secs
#
# Epoch 2 Batch 0 Loss 4.5164 Accuracy 0.0645
# Epoch 2 Batch 50 Loss 4.1501 Accuracy 0.0736
# Epoch 2 Batch 0 Validation Loss 3.6099 Validation Accuracy 0.0806
# Epoch 2 Loss 4.0115 Accuracy 0.0761
# Epoch 2 Validation Loss 3.6982 Validation Accuracy 0.0801
# Time taken for 1 epoch: 57.261988162994385 secs
#
# Epoch 3 Batch 0 Loss 3.7251 Accuracy 0.0794
# Epoch 3 Batch 50 Loss 3.4607 Accuracy 0.0866
# Epoch 3 Batch 0 Validation Loss 3.4218 Validation Accuracy 0.0827
# Epoch 3 Loss 3.4099 Accuracy 0.0875
# Epoch 3 Validation Loss 3.3697 Validation Accuracy 0.0864
# Time taken for 1 epoch: 56.63111352920532 secs
#
# Epoch 4 Batch 0 Loss 3.1946 Accuracy 0.0847
# Epoch 4 Batch 50 Loss 3.0838 Accuracy 0.0949
# Epoch 4 Batch 0 Validation Loss 3.2960 Validation Accuracy 0.0919
# Epoch 4 Loss 3.0719 Accuracy 0.0947
# Epoch 4 Validation Loss 3.2471 Validation Accuracy 0.0908
# Time taken for 1 epoch: 56.71091866493225 secs
#
# Epoch 5 Batch 0 Loss 3.0036 Accuracy 0.0946
# Epoch 5 Batch 50 Loss 2.8287 Accuracy 0.1009
# Epoch 5 Batch 0 Validation Loss 3.1822 Validation Accuracy 0.0893
# Epoch 5 Loss 2.8304 Accuracy 0.1007
# Epoch 5 Validation Loss 3.1632 Validation Accuracy 0.0923
# Time taken for 1 epoch: 56.521788358688354 secs
#
# Epoch 6 Batch 0 Loss 2.8263 Accuracy 0.1001
# Epoch 6 Batch 50 Loss 2.6119 Accuracy 0.1068
# Epoch 6 Batch 0 Validation Loss 3.1269 Validation Accuracy 0.0861
# Epoch 6 Loss 2.6225 Accuracy 0.1062
# Epoch 6 Validation Loss 3.2165 Validation Accuracy 0.0890
# Time taken for 1 epoch: 56.794739723205566 secs
#
# Epoch 7 Batch 0 Loss 2.5056 Accuracy 0.1057
# Epoch 7 Batch 50 Loss 2.4054 Accuracy 0.1127
# Epoch 7 Batch 0 Validation Loss 3.1325 Validation Accuracy 0.0871
# Epoch 7 Loss 2.4322 Accuracy 0.1118
# Epoch 7 Validation Loss 3.2132 Validation Accuracy 0.0873
# Time taken for 1 epoch: 56.59795522689819 secs
#
# Epoch 8 Batch 0 Loss 2.3585 Accuracy 0.1099
# Epoch 8 Batch 50 Loss 2.2395 Accuracy 0.1182
# Epoch 8 Batch 0 Validation Loss 3.2916 Validation Accuracy 0.0920
# Epoch 8 Loss 2.2592 Accuracy 0.1171
# Epoch 8 Validation Loss 3.2472 Validation Accuracy 0.0895
# Time taken for 1 epoch: 56.3563129901886 secs
#
# Epoch 9 Batch 0 Loss 2.2292 Accuracy 0.1131
# Epoch 9 Batch 50 Loss 2.0563 Accuracy 0.1246
# Epoch 9 Batch 0 Validation Loss 3.2723 Validation Accuracy 0.0916
# Epoch 9 Loss 2.0998 Accuracy 0.1226
# Epoch 9 Validation Loss 3.3424 Validation Accuracy 0.0899
# Time taken for 1 epoch: 56.383206605911255 secs
#
# Epoch 10 Batch 0 Loss 2.0107 Accuracy 0.1177
# Epoch 10 Batch 50 Loss 1.9151 Accuracy 0.1285
# Epoch 10 Batch 0 Validation Loss 3.4251 Validation Accuracy 0.0881
# Epoch 10 Loss 1.9641 Accuracy 0.1273
# Epoch 10 Validation Loss 3.3543 Validation Accuracy 0.0887
# Time taken for 1 epoch: 54.353344202041626 secs
#
# Epoch 11 Batch 0 Loss 1.9396 Accuracy 0.1279
# Epoch 11 Batch 50 Loss 1.7886 Accuracy 0.1334
# Epoch 11 Batch 0 Validation Loss 3.5137 Validation Accuracy 0.0889
# Epoch 11 Loss 1.8408 Accuracy 0.1314
# Epoch 11 Validation Loss 3.4433 Validation Accuracy 0.0867
# Time taken for 1 epoch: 55.04881048202515 secs
#
# Epoch 12 Batch 0 Loss 1.7849 Accuracy 0.1302
# Epoch 12 Batch 50 Loss 1.6511 Accuracy 0.1390
# Epoch 12 Batch 0 Validation Loss 3.7865 Validation Accuracy 0.0776
# Epoch 12 Loss 1.6960 Accuracy 0.1372
# Epoch 12 Validation Loss 3.5347 Validation Accuracy 0.0866
# Time taken for 1 epoch: 54.71612739562988 secs
#
# Epoch 13 Batch 0 Loss 1.5801 Accuracy 0.1445
# Epoch 13 Batch 50 Loss 1.4777 Accuracy 0.1468
# Epoch 13 Batch 0 Validation Loss 3.5929 Validation Accuracy 0.0904
# Epoch 13 Loss 1.5147 Accuracy 0.1452
# Epoch 13 Validation Loss 3.6359 Validation Accuracy 0.0902
# Time taken for 1 epoch: 54.81493091583252 secs
#
# Epoch 14 Batch 0 Loss 1.3723 Accuracy 0.1450
# Epoch 14 Batch 50 Loss 1.3238 Accuracy 0.1541
# Epoch 14 Batch 0 Validation Loss 3.6209 Validation Accuracy 0.0946
# Epoch 14 Loss 1.3566 Accuracy 0.1527
# Epoch 14 Validation Loss 3.7060 Validation Accuracy 0.0905
# Time taken for 1 epoch: 55.23328995704651 secs
#
# Epoch 15 Batch 0 Loss 1.2335 Accuracy 0.1515
# Epoch 15 Batch 50 Loss 1.1888 Accuracy 0.1613
# Epoch 15 Batch 0 Validation Loss 3.7685 Validation Accuracy 0.0930
# Epoch 15 Loss 1.2203 Accuracy 0.1600
# Epoch 15 Validation Loss 3.8034 Validation Accuracy 0.0868
# Time taken for 1 epoch: 55.21192669868469 secs
#
# Epoch 16 Batch 0 Loss 1.1188 Accuracy 0.1652
# Epoch 16 Batch 50 Loss 1.0662 Accuracy 0.1679
# Epoch 16 Batch 0 Validation Loss 3.6760 Validation Accuracy 0.0900
# Epoch 16 Loss 1.0999 Accuracy 0.1663
# Epoch 16 Validation Loss 3.8915 Validation Accuracy 0.0878
# Time taken for 1 epoch: 55.02701544761658 secs
#
# Epoch 17 Batch 0 Loss 1.0006 Accuracy 0.1705
# Epoch 17 Batch 50 Loss 0.9679 Accuracy 0.1737
# Epoch 17 Batch 0 Validation Loss 3.8653 Validation Accuracy 0.0888
# Epoch 17 Loss 1.0019 Accuracy 0.1716
# Epoch 17 Validation Loss 4.0069 Validation Accuracy 0.0898
# Time taken for 1 epoch: 55.136534214019775 secs
#
# Epoch 18 Batch 0 Loss 0.9037 Accuracy 0.1774
# Epoch 18 Batch 50 Loss 0.8859 Accuracy 0.1780
# Epoch 18 Batch 0 Validation Loss 4.1520 Validation Accuracy 0.0868
# Epoch 18 Loss 0.9179 Accuracy 0.1761
# Epoch 18 Validation Loss 4.0823 Validation Accuracy 0.0883
# Time taken for 1 epoch: 55.52273154258728 secs
#
# Epoch 19 Batch 0 Loss 0.8363 Accuracy 0.1781
# Epoch 19 Batch 50 Loss 0.8229 Accuracy 0.1815
# Epoch 19 Batch 0 Validation Loss 4.0931 Validation Accuracy 0.0925
# Epoch 19 Loss 0.8477 Accuracy 0.1804
# Epoch 19 Validation Loss 4.1895 Validation Accuracy 0.0887
# Time taken for 1 epoch: 55.80459904670715 secs
#
# Epoch 20 Batch 0 Loss 0.7680 Accuracy 0.1881
# Epoch 20 Batch 50 Loss 0.7589 Accuracy 0.1850
# Epoch 20 Batch 0 Validation Loss 4.0090 Validation Accuracy 0.0857
# Epoch 20 Loss 0.7851 Accuracy 0.1840
# Epoch 20 Validation Loss 4.2104 Validation Accuracy 0.0854
# Time taken for 1 epoch: 54.99594974517822 secs
#
# Epoch 21 Batch 0 Loss 0.7558 Accuracy 0.1887
# Epoch 21 Batch 50 Loss 0.7158 Accuracy 0.1883
# Epoch 21 Batch 0 Validation Loss 4.4542 Validation Accuracy 0.0833
# Epoch 21 Loss 0.7384 Accuracy 0.1871
# Epoch 21 Validation Loss 4.3313 Validation Accuracy 0.0856
# Time taken for 1 epoch: 55.38570523262024 secs

# %%
plt.figure(figsize=(10,5))
plt.title("Training and Validation Loss")
plt.plot(val_losses,label="val")
plt.plot(train_losses,label="train")
plt.xlabel("iterations")
plt.ylabel("Loss")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,5))
plt.title("Training and Validation Accuracy")
plt.plot(val_accuracies,label="val")
plt.plot(train_accuracies,label="train")
plt.xlabel("iterations")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# %%
from nltk.translate.bleu_score import sentence_bleu

# %%
def evaluate(image):
   temp_input = tf.expand_dims(decode_and_resize(image), 0)
   img_tensor_val = cnn_model(temp_input)
  #  img_tensor_val = tf.reshape(img_tensor_val, (img_tensor_val.shape[0], -1, img_tensor_val.shape[3]))
   start_token = word_to_index(tf.constant('<start>'))
   end_token = word_to_index(tf.constant('<end>'))
   decoder_input = [start_token]
   output = tf.expand_dims(decoder_input, 0) #tokens
   result = [] #word list

   for i in range(100):
      dec_mask = create_masks_decoder(output)
      predictions, attention_weights = transformer(img_tensor_val,output,False,dec_mask)
      # print(predictions.shape)
      # print(output.shape)


      predictions = predictions[: ,-1:, :]  # (batch_size, 1, vocab_size)
      predicted_id = tf.cast(tf.argmax(predictions, axis=-1), tf.int64)
      if predicted_id == end_token:
         return result,tf.squeeze(output, axis=0), attention_weights
      result.append(tf.compat.as_text(index_to_word(int(predicted_id.numpy())).numpy()))
      output = tf.concat([output, predicted_id], axis=-1)

   return result,tf.squeeze(output, axis=0), attention_weights

# %%
#  rid = np.random.randint(0, len(test_images))

def test_single_img(id):
  test_images = list(testing_data.keys())
  image = test_images[id]

  captions = testing_data[image]
  bleu_scores = []
  for caption in captions:
    real_caption = ' '.join([tf.compat.as_text(index_to_word(i).numpy()) for i in vectorization(caption) if i not in [0]])
    caption,result,attention_weights = evaluate(image)

    first = real_caption.split(' ', 1)[1]
    real_caption = first.rsplit(' ', 1)[0]

    for i in caption:
      if i=="<unk>":
          caption.remove(i)

    for i in real_caption:
      if i=="<unk>":
          real_caption.remove(i)

    result_join = ' '.join(caption)
    result_final = result_join.rsplit(' ', 1)[0]
    real_appn = []
    real_appn.append(real_caption.split())
    reference = real_appn
    candidate = caption

    # score = sentence_bleu(reference, candidate, weights=(1.0,0,0,0))
    # print(f"BLEU-1 score: {score*100}")
    # score = sentence_bleu(reference, candidate, weights=(0.5,0.5,0,0))
    # print(f"BLEU-2 score: {score*100}")
    # score = sentence_bleu(reference, candidate, weights=(0.3,0.3,0.3,0))
    # print(f"BLEU-3 score: {score*100}")
    score = sentence_bleu(reference, candidate, weights=(0.25,0.25,0.25,0.25))
    bleu_scores.append(score)
    print(f"BLEU-4 score: {score*100}")

    print ('Real Caption:', real_caption)
    print ('Predicted Caption:', ' '.join(caption))
    temp_image = np.array(Image.open(image))
    plt.imshow(temp_image)

  return np.mean(bleu_scores)

# %%
test_single_img(0)
# Out:
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 3-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# BLEU-4 score: 26.176079745548464
# Real Caption: football players wearing orange uniforms are tackling a player in a white uniform
# Predicted Caption: two oklahoma sooner football players talk on the sideline
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# BLEU-4 score: 57.735026918962575
# Real Caption: a tackle in a football game
# Predicted Caption: two oklahoma sooner football players talk on the sideline
# BLEU-4 score: 0
# Real Caption: three footballers in a tackle
# Predicted Caption: two oklahoma sooner football players talk on the sideline
# BLEU-4 score: 41.36895450425725
# Real Caption: three men are involved in a football game are tackling each other
# Predicted Caption: two oklahoma sooner football players talk on the sideline
# BLEU-4 score: 52.35215949109693
# Real Caption: two players take down the player with the ball in a football game
# Predicted Caption: two oklahoma sooner football players talk on the sideline
# 0.35526444131973045

# %%
bleu_scores = []
for i in range(len(testing_data)):
  bleu_score = test_single_img(i)
  bleu_scores.append(bleu_score)

np.mean(bleu_scores)
# Out:
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 3-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# BLEU-4 score: 26.176079745548464
# Real Caption: football players wearing orange uniforms are tackling a player in a white uniform
# Predicted Caption: two oklahoma sooner football players talk on the sideline
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 2-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# BLEU-4 score: 57.735026918962575
# Real Caption: a tackle in a football game
# Predicted Caption: two oklahoma sooner football players talk on the sideline
# BLEU-4 score: 0
# Real Caption: three footballers in a tackle
# Predicted Caption: two oklahoma sooner football players talk on the sideline
# BLEU-4 score: 41.36895450425725
# Real Caption: three men are involved in a football game are tackling each other
# Predicted Caption: two oklahoma sooner football players talk on the sideline
# BLEU-4 score: 52.35215949109693
# Real Caption: two players take down the player with the ball in a football game
# Predicted Caption: two oklahoma sooner football players talk on the sideline
# BLEU-4 score: 59.46035575013605
# Real Caption: a goalie is guarding the goal
# Predicted Caption: two construction workers working on a roof top
# BLEU-4 score: 0
# Real Caption: kids in helmets play hockey outside
# Predicted Caption: two construction workers working on a roof top
# BLEU-4 score: 48.59869096699081
# Real Caption: several players playing a game of hockey outside on the road
# Predicted Caption: two construction workers working on a roof top
# BLEU-4 score: 0
# Real Caption: some children play hockey outside
# Predicted Caption: two construction workers working on a roof top
# BLEU-4 score: 55.06953149031838
# Real Caption: two children play street hockey in front of a goal
# Predicted Caption: two construction workers working on a roof top
# BLEU-4 score: 57.735026918962575
# Real Caption: a bald man climbing rocks
# Predicted Caption: a person on a rock holding onto a rock
# BLEU-4 score: 68.65890479690393
# Real Caption: a bald shirtless man rock climbing
# Predicted Caption: a person on a rock holding onto a rock
# BLEU-4 score: 68.65890479690393
# Real Caption: a man climbing up a rocky cliff
# Predicted Caption: a person on a rock holding onto a rock
# BLEU-4 score: 75.98356856515926
# Real Caption: a man with no shirt on is rock climbing
# Predicted Caption: a person on a rock holding onto a rock
# BLEU-4 score: 45.180100180492246
# Real Caption: a rock climber scales a mountain
# Predicted Caption: a person on a rock holding onto a rock
# BLEU-4 score: 13.867166349083973
# Real Caption: a brown dog running on shore with a boat in the background
# Predicted Caption: dogs playing in the water
# BLEU-4 score: 37.69486629893372
# Real Caption: a brown dog runs near the water
# Predicted Caption: dogs playing in the water
# BLEU-4 score: 13.501633901742352
# Real Caption: a dog is running on the grass beside a boat on the river
# Predicted Caption: dogs playing in the water
# BLEU-4 score: 3.684655318513789
# Real Caption: a large orange dog runs through the grass by the water where a large boat is sailing in the background
# Predicted Caption: dogs playing in the water
# BLEU-4 score: 22.290865704882616
# Real Caption: the dog is running in the grass next to the water
# Predicted Caption: dogs playing in the water
# BLEU-4 score: 33.649324423301515
# Real Caption: a man carrying a fishing pole silhouetted against a bright blue sky
# Predicted Caption: a man stands on the hill close to the base of the hill
# BLEU-4 score: 40.01601601922499
# Real Caption: a person stands on a hill surrounded by blue skies and clouds
# Predicted Caption: a man stands on the hill close to the base of the hill
# BLEU-4 score: 52.66403878479265
# Real Caption: a person with a fishing pole is backlit against a blue cloudy sky
# Predicted Caption: a man stands on the hill close to the base of the hill
# BLEU-4 score: 62.62844962765469
# Real Caption: a person with a fishing pole silhouetted in front of a blue sky
# Predicted Caption: a man stands on the hill close to the base of the hill
# BLEU-4 score: 37.23909894939823
# Real Caption: a silhouette of a man with a fishing pole
# Predicted Caption: a man stands on the hill close to the base of the hill
# BLEU-4 score: 35.5310106137518
# Real Caption: a man is sitting in room made up of wood [UNK]
# Predicted Caption: a group of people sitting in a restaurant
# BLEU-4 score: 42.45672557693626
# Real Caption: a man sits at a table in a room
# Predicted Caption: a group of people sitting in a restaurant
# /usr/local/lib/python3.7/dist-packages/nltk/translate/bleu_score.py:490: UserWarning:
# Corpus/Sentence contains 0 counts of 4-gram overlaps.
# BLEU scores might be undesirable; use SmoothingFunction().
#   warnings.warn(_msg)
# Streaming output truncated to the last 5000 lines.
# Real Caption: a person with a black and red outfit and a black hood is up in the air
# Predicted Caption: a boy in a red sweatshirt is jumping on the street
# BLEU-4 score: 65.29942057256105
# Real Caption: a young ninja jumps into the air
# Predicted Caption: a boy in a red sweatshirt is jumping on the street
# BLEU-4 score: 70.71067811865476
# Real Caption: a boy and his dog are standing on a trampoline enjoying each others company
# Predicted Caption: a brown and white dog is running in the snow with a black and white toy
# BLEU-4 score: 65.80370064762462
# Real Caption: a boy looks at a dog while they stand on a trampoline outside
# Predicted Caption: a brown and white dog is running in the snow with a black and white toy
# BLEU-4 score: 35.93041119630843
# Real Caption: a buy with glasses petting his bulldog on the pavement with woods in the background
# Predicted Caption: a brown and white dog is running in the snow with a black and white toy
# BLEU-4 score: 70.71067811865476
# Real Caption: a muscular dog with upturned face looking into eyes of a young boy
# Predicted Caption: a brown and white dog is running in the snow with a black and white toy
# BLEU-4 score: 65.80370064762462
# Real Caption: dog with tongue out looking up at a young boy with glasses
# Predicted Caption: a brown and white dog is running in the snow with a black and white toy
# BLEU-4 score: 42.494561961344395
# Real Caption: a smiling woman with red lips wearing a white sweater and black hat is waving
# Predicted Caption: a girl in a red jacket and white and black sweater is smiling up in the air having come her way through a white
# BLEU-4 score: 63.89431042462724
# Real Caption: a [UNK] woman with black hair stands smiling and waving among dried corn stalks
# Predicted Caption: a girl in a red jacket and white and black sweater is smiling up in the air having come her way through a white
# BLEU-4 score: 27.151607333166954
# Real Caption: a woman in a yellow fluffy shirt waving next to dried corn husks
# Predicted Caption: a girl in a red jacket and white and black sweater is smiling up in the air having come her way through a white
# BLEU-4 score: 63.89431042462724
# Real Caption: a woman waving at the camera and smiling
# Predicted Caption: a girl in a red jacket and white and black sweater is smiling up in the air having come her way through a white
# BLEU-4 score: 45.18010018049224
# Real Caption: a woman waving from between two piles of dried corn [UNK]
# Predicted Caption: a girl in a red jacket and white and black sweater is smiling up in the air having come her way through a white
# BLEU-4 score: 41.53509237206396
# Real Caption: a black dog jumping through some water
# Predicted Caption: a black dog is running through the water
# BLEU-4 score: 45.96613576124592
# Real Caption: a black dog leaps out of the water
# Predicted Caption: a black dog is running through the water
# BLEU-4 score: 61.47881529512643
# Real Caption: a black dog runs through the water
# Predicted Caption: a black dog is running through the water
# BLEU-4 score: 45.96613576124592
# Real Caption: a black dog splashes in the water
# Predicted Caption: a black dog is running through the water
# BLEU-4 score: 36.6545903669115
# Real Caption: a large black dog is playing in the ocean
# Predicted Caption: a black dog is running through the water
# BLEU-4 score: 24.60137257692754
# Real Caption: a black dog is running across a field
# Predicted Caption: a black dog running through the grass with an orange toy in its mouth
# BLEU-4 score: 19.049210498698702
# Real Caption: a black dog is running in a field of grass and another black dog can be seen behind him
# Predicted Caption: a black dog running through the grass with an orange toy in its mouth
# BLEU-4 score: 18.798317647335086
# Real Caption: the two black dogs are running through the grass
# Predicted Caption: a black dog running through the grass with an orange toy in its mouth
# BLEU-4 score: 40.71220775553065
# Real Caption: two black dogs are running in the grass together
# Predicted Caption: a black dog running through the grass with an orange toy in its mouth
# BLEU-4 score: 68.03749333171201
# Real Caption: two black dogs run through a field
# Predicted Caption: a black dog running through the grass with an orange toy in its mouth
# BLEU-4 score: 26.78284959130086
# Real Caption: a baseball player is tagged out sliding into second base
# Predicted Caption: a baseball player swings for the ball
# BLEU-4 score: 41.11336169005197
# Real Caption: a baseball player slides toward a base
# Predicted Caption: a baseball player swings for the ball
# BLEU-4 score: 40.04970149398301
# Real Caption: a man in a grey uniform sliding into a base
# Predicted Caption: a baseball player swings for the ball
# BLEU-4 score: 61.47881529512643
# Real Caption: three men playing baseball
# Predicted Caption: a baseball player swings for the ball
# BLEU-4 score: 20.211771013895866
# Real Caption: two [UNK] are defending the base as a member of the batting team slide towards it
# Predicted Caption: a baseball player swings for the ball
# BLEU-4 score: 74.00828044922852
# Real Caption: a man is laying down inside a black [UNK] boat
# Predicted Caption: a young man wearing jeans and red pants is skateboarding
# BLEU-4 score: 49.541500283078236
# Real Caption: a man lays down to rest inside a wood structure against a building
# Predicted Caption: a young man wearing jeans and red pants is skateboarding
# BLEU-4 score: 66.8740304976422
# Real Caption: a man sleeping on a sheltered public bench
# Predicted Caption: a young man wearing jeans and red pants is skateboarding
# BLEU-4 score: 40.616605477846655
# Real Caption: a man sleeps in the lining of a boat that is propped against a brick wall
# Predicted Caption: a young man wearing jeans and red pants is skateboarding
# BLEU-4 score: 74.00828044922852
# Real Caption: man is lying down inside of a black structure outdoors
# Predicted Caption: a young man wearing jeans and red pants is skateboarding
# BLEU-4 score: 57.73502691896258
# Real Caption: a baby with food all over its mouth
# Predicted Caption: a baby is holding a baby in its mouth
# BLEU-4 score: 68.65890479690393
# Real Caption: a little boy with baby food on his face
# Predicted Caption: a baby is holding a baby in its mouth
# BLEU-4 score: 32.80443278078623
# Real Caption: an adult hods a baby wearing a bib the baby has food around its mouth
# Predicted Caption: a baby is holding a baby in its mouth
# BLEU-4 score: 38.8751420414402
# Real Caption: the baby is wearing a bib and sitting in an adult
# Predicted Caption: a baby is holding a baby in its mouth
# BLEU-4 score: 36.17739608204856
# Real Caption: there is a baby with [UNK] lips staring at the camera
# Predicted Caption: a baby is holding a baby in its mouth
# BLEU-4 score: 46.08636396914616
# Real Caption: three men standing in the tide at a beach
# Predicted Caption: two people walking along the beach
# BLEU-4 score: 36.409302398068725
# Real Caption: three men stand on the beach fully clothed
# Predicted Caption: two people walking along the beach
# BLEU-4 score: 54.085366098934806
# Real Caption: three men wade into the ocean shore
# Predicted Caption: two people walking along the beach
# BLEU-4 score: 54.44460596606694
# Real Caption: three people in jackets at a rocky beach
# Predicted Caption: two people walking along the beach
# BLEU-4 score: 75.98356856515926
# Real Caption: three people on a beach
# Predicted Caption: two people walking along the beach
# BLEU-4 score: 31.55431780782437
# Real Caption: a girl in a dress is jumping in the air with legs bent while another girl in pink watches
# Predicted Caption: two young girls dressed in green outfits walking around a track
# BLEU-4 score: 54.91004867761124
# Real Caption: a girl jumps into the air while another girl watches
# Predicted Caption: two young girls dressed in green outfits walking around a track
# BLEU-4 score: 34.92059300639711
# Real Caption: a young girl is jumping on carpet while another girl standing in front of her looks to the left
# Predicted Caption: two young girls dressed in green outfits walking around a track
# BLEU-4 score: 65.29942057256105
# Real Caption: the two little girls jump on the bed
# Predicted Caption: two young girls dressed in green outfits walking around a track
# BLEU-4 score: 65.29942057256105
# Real Caption: two little girls jump above the floor
# Predicted Caption: two young girls dressed in green outfits walking around a track
# BLEU-4 score: 40.01601601922499
# Real Caption: a white and black dog and a brown dog in sandy terrain
# Predicted Caption: two dogs one brown and one black dog fighting on the other dogs
# BLEU-4 score: 62.62844962765469
# Real Caption: a [UNK] dog chases a doberman on a beach
# Predicted Caption: two dogs one brown and one black dog fighting on the other dogs
# BLEU-4 score: 42.311785416105785
# Real Caption: one dog is chasing another one on the beach
# Predicted Caption: two dogs one brown and one black dog fighting on the other dogs
# BLEU-4 score: 69.30977286178778
# Real Caption: the two large dogs are running through sand
# Predicted Caption: two dogs one brown and one black dog fighting on the other dogs
# BLEU-4 score: 74.47819789879647
# Real Caption: two large dogs chasing each other at the beach
# Predicted Caption: two dogs one brown and one black dog fighting on the other dogs
# BLEU-4 score: 61.47881529512643
# Real Caption: two girls are riding a 4 wheeler
# Predicted Caption: four people are deep on the sand
# BLEU-4 score: 14.08903092257678
# Real Caption: two girls are sitting on an atv on the sand in front of a bridge
# Predicted Caption: four people are deep on the sand
# BLEU-4 score: 0
# Real Caption: two girls riding an atv
# Predicted Caption: four people are deep on the sand
# BLEU-4 score: 29.765372490051632
# Real Caption: two kids are posing on a black atv that is on top of sand
# Predicted Caption: four people are deep on the sand
# BLEU-4 score: 0
# Real Caption: two young girls drive an atv
# Predicted Caption: four people are deep on the sand
# BLEU-4 score: 60.59285518620335
# Real Caption: a lone man casting a fishing line into the water at sunset
# Predicted Caption: a young person with a rock wall in the background
# BLEU-4 score: 42.728700639623405
# Real Caption: a man is fishing in the ocean at dusk
# Predicted Caption: a young person with a rock wall in the background
# BLEU-4 score: 44.88829116506817
# Real Caption: a man is standing on some rocks and casting a fishing line into the ocean
# Predicted Caption: a young person with a rock wall in the background
# BLEU-4 score: 60.59285518620335
# Real Caption: a man looks at the sunset and the ocean seen in silhouette
# Predicted Caption: a young person with a rock wall in the background
# BLEU-4 score: 74.00828044922852
# Real Caption: person fishing in large body of water with low sunlight
# Predicted Caption: a young person with a rock wall in the background
# BLEU-4 score: 65.29942057256105
# Real Caption: a girl at a wedding holding some orange flowers
# Predicted Caption: a group of girls are standing outside under a [UNK] tree
# BLEU-4 score: 72.26568811456053
# Real Caption: a girl holds a bouquet of flowers
# Predicted Caption: a group of girls are standing outside under a [UNK] tree
# BLEU-4 score: 65.9858515800358
# Real Caption: a little girl at a wedding holds a bouquet of orange flowers
# Predicted Caption: a group of girls are standing outside under a [UNK] tree
# BLEU-4 score: 50.23505432440377
# Real Caption: a little girl holds orange [UNK] while others celebrate an occasion in a garden setting
# Predicted Caption: a group of girls are standing outside under a [UNK] tree
# BLEU-4 score: 0
# Real Caption: young girl in orange dress holding orange flowers
# Predicted Caption: a group of girls are standing outside under a [UNK] tree
# BLEU-4 score: 61.47881529512643
# Real Caption: a black dog chasing geese
# Predicted Caption: a large dog and a small dog run in a field of brown grass
# BLEU-4 score: 61.47881529512643
# Real Caption: a dog chases two geese
# Predicted Caption: a large dog and a small dog run in a field of brown grass
# BLEU-4 score: 73.11104457090248
# Real Caption: a dog chasing 2 geese in an open field
# Predicted Caption: a large dog and a small dog run in a field of brown grass
# BLEU-4 score: 30.130404892785684
# Real Caption: a large black dog is chasing two geese in a field
# Predicted Caption: a large dog and a small dog run in a field of brown grass
# BLEU-4 score: 68.03749333171201
# Real Caption: dog runs after two geese in field
# Predicted Caption: a large dog and a small dog run in a field of brown grass
# BLEU-4 score: 39.2814650900513
# Real Caption: a bearded man reads while sitting on a wall in a park
# Predicted Caption: a person wearing a red shirt is sitting on the pavement near a wooden fence
# BLEU-4 score: 34.5720784641941
# Real Caption: a man reads his paper on the bench
# Predicted Caption: a person wearing a red shirt is sitting on the pavement near a wooden fence
# BLEU-4 score: 19.5647514979229
# Real Caption: a man wearing a red shirt sits on a cement bench and reads the paper
# Predicted Caption: a person wearing a red shirt is sitting on the pavement near a wooden fence
# BLEU-4 score: 50.813274815461476
# Real Caption: an old man sits outside reading a newspaper
# Predicted Caption: a person wearing a red shirt is sitting on the pavement near a wooden fence
# BLEU-4 score: 60.42750794713536
# Real Caption: an old man with a white beard is reading
# Predicted Caption: a person wearing a red shirt is sitting on the pavement near a wooden fence
# BLEU-4 score: 56.23413251903491
# Real Caption: a boy balances on something inflatable
# Predicted Caption: a man in a yellow kayak is in the water
# BLEU-4 score: 27.92504378041133
# Real Caption: a boy tries to keep his balance while standing on two floating devices while two others watch
# Predicted Caption: a man in a yellow kayak is in the water
# BLEU-4 score: 26.581560693718632
# Real Caption: a kid wearing safety gear stands on some material in the water
# Predicted Caption: a man in a yellow kayak is in the water
# BLEU-4 score: 18.325568129983203
# Real Caption: little kids play in the water while their friend poses on top of their raft
# Predicted Caption: a man in a yellow kayak is in the water
# BLEU-4 score: 13.200012392340058
# Real Caption: there are two children in the water and one balancing on a float and they are all wearing helmets
# Predicted Caption: a man in a yellow kayak is in the water
# BLEU-4 score: 31.466609969564153
# Real Caption: a bike rider flipping over a black ramp
# Predicted Caption: a person in a yellow jacket and a black hat is waiting in front of a white building
# BLEU-4 score: 63.89431042462724
# Real Caption: a cyclist does a flip in the air
# Predicted Caption: a person in a yellow jacket and a black hat is waiting in front of a white building
# BLEU-4 score: 33.81307292971254
# Real Caption: a man performs motorbike tricks off a ramp in a stadium
# Predicted Caption: a person in a yellow jacket and a black hat is waiting in front of a white building
# BLEU-4 score: 35.75297164449809
# Real Caption: a person rides a jump high into the air and upside down on a bicycle
# Predicted Caption: a person in a yellow jacket and a black hat is waiting in front of a white building
# BLEU-4 score: 57.735026918962575
# Real Caption: motorcyclist upside down in midair during a daring [UNK]
# Predicted Caption: a person in a yellow jacket and a black hat is waiting in front of a white building
# BLEU-4 score: 37.90562132075204
# Real Caption: a couple sits on a floral couch while an older woman in the background smiles
# Predicted Caption: a woman holds a large mirror of which are sitting on a red couch
# BLEU-4 score: 40.71220775553065
# Real Caption: a couple sitting together on a flowered sofa with an older woman
# Predicted Caption: a woman holds a large mirror of which are sitting on a red couch
# BLEU-4 score: 40.04970149398301
# Real Caption: a man and woman have their arms around each other while an older woman in orange sits next to them
# Predicted Caption: a woman holds a large mirror of which are sitting on a red couch
# BLEU-4 score: 40.71220775553065
# Real Caption: a man and woman hug on a couch while another woman smiles
# Predicted Caption: a woman holds a large mirror of which are sitting on a red couch
# BLEU-4 score: 40.71220775553065
# Real Caption: a man and woman pose on a couch
# Predicted Caption: a woman holds a large mirror of which are sitting on a red couch
# BLEU-4 score: 23.356898886410004
# Real Caption: a biker performs a trick in the air
# Predicted Caption: a person doing stunt on a bicycle with no hands in the air on a bike
# BLEU-4 score: 27.05411345269698
# Real Caption: a child rides a bike high in the air
# Predicted Caption: a person doing stunt on a bicycle with no hands in the air on a bike
# BLEU-4 score: 22.14250071345737
# Real Caption: a person flying through the air on a bicycle
# Predicted Caption: a person doing stunt on a bicycle with no hands in the air on a bike
# BLEU-4 score: 42.72870063962341
# Real Caption: a person is jumping while riding a bike
# Predicted Caption: a person doing stunt on a bicycle with no hands in the air on a bike
# BLEU-4 score: 29.346699841875935
# Real Caption: a person on a bike flies through the air with the sun [UNK] through the bike frame
# Predicted Caption: a person doing stunt on a bicycle with no hands in the air on a bike
# BLEU-4 score: 38.84935863283276
# Real Caption: a buy is grinding a rail on a snowboard
# Predicted Caption: a man skiing on a [UNK] sign
# BLEU-4 score: 38.84935863283276
# Real Caption: a person is jumping a ramp on a snowboard
# Predicted Caption: a man skiing on a [UNK] sign
# BLEU-4 score: 73.11104457090248
# Real Caption: a snowboarder goes down a ramp
# Predicted Caption: a man skiing on a [UNK] sign
# BLEU-4 score: 73.11104457090248
# Real Caption: a snowboarder going over a ramp
# Predicted Caption: a man skiing on a [UNK] sign
# BLEU-4 score: 52.70837136273565
# Real Caption: a snowboarder performs a jump on the clean white snow
# Predicted Caption: a man skiing on a [UNK] sign
# BLEU-4 score: 42.88819424803535
# Real Caption: a boy with his mouth open and tongue sticking out clinging to a bar next to a platform
# Predicted Caption: a young girl sitting on a wooden structure near a playground equipment
# BLEU-4 score: 63.89431042462724
# Real Caption: a [UNK] climbs a [UNK] as he sticks out his tongue
# Predicted Caption: a young girl sitting on a wooden structure near a playground equipment
# BLEU-4 score: 63.89431042462724
# Real Caption: a small boy climbing a backyard play set
# Predicted Caption: a young girl sitting on a wooden structure near a playground equipment
# BLEU-4 score: 41.999739844885475
# Real Caption: a young boy with his tongue stuck out is climbing onto a wooden platform
# Predicted Caption: a young girl sitting on a wooden structure near a playground equipment
# BLEU-4 score: 0
# Real Caption: the boy is climbing
# Predicted Caption: a young girl sitting on a wooden structure near a playground equipment
# BLEU-4 score: 0
# Real Caption: a man gazes over the rail in the peaceful early morning
# Predicted Caption: people are sitting on large fishing with leather jacket and colorful knee high boots on it and white ground
# BLEU-4 score: 47.89736254435746
# Real Caption: a man looks out at the water under a bridge and against a skyline
# Predicted Caption: people are sitting on large fishing with leather jacket and colorful knee high boots on it and white ground
# BLEU-4 score: 0
# Real Caption: a man looks over a railing into the water
# Predicted Caption: people are sitting on large fishing with leather jacket and colorful knee high boots on it and white ground
# BLEU-4 score: 56.95988432761473
# Real Caption: man leaning on railing with [UNK] behind him
# Predicted Caption: people are sitting on large fishing with leather jacket and colorful knee high boots on it and white ground
# BLEU-4 score: 63.03647413359293
# Real Caption: man with white undershirt and blue pants standing at fence with red top rail near a bridge
# Predicted Caption: people are sitting on large fishing with leather jacket and colorful knee high boots on it and white ground
# BLEU-4 score: 21.55064730781546
# Real Caption: a fluffy white dog runs through the woods with his ears flapping in the breeze
# Predicted Caption: a white dog with a red leash running
# BLEU-4 score: 42.57178634163133
# Real Caption: a small white dog is running across a grassy field
# Predicted Caption: a white dog with a red leash running
# BLEU-4 score: 36.55552228545123
# Real Caption: a white dog runs in the grass
# Predicted Caption: a white dog with a red leash running
# BLEU-4 score: 31.592032296154628
# Real Caption: a white dog wearing a red harness runs though the woods
# Predicted Caption: a white dog with a red leash running
# BLEU-4 score: 27.6715788893083
# Real Caption: the little white dog wearing the red collar is running in the grass
# Predicted Caption: a white dog with a red leash running
# BLEU-4 score: 70.71067811865476
# Real Caption: a guy with a scarf and woven toboggan
# Predicted Caption: a woman in a red coat wearing a red hat and jacket
# BLEU-4 score: 70.71067811865476
# Real Caption: a man in black and white cap and scarf
# Predicted Caption: a woman in a red coat wearing a red hat and jacket
# BLEU-4 score: 44.11629359322706
# Real Caption: a man wearing a scarf and knitted hat is smiling
# Predicted Caption: a woman in a red coat wearing a red hat and jacket
# BLEU-4 score: 52.463410228614585
# Real Caption: a person wearing a hat and scarf looks to the right
# Predicted Caption: a woman in a red coat wearing a red hat and jacket
# BLEU-4 score: 63.89431042462724
# Real Caption: the man has a [UNK] on top of his [UNK] hat
# Predicted Caption: a woman in a red coat wearing a red hat and jacket
# BLEU-4 score: 37.69486629893372
# Real Caption: boy and girl running along the beach
# Predicted Caption: people walking on the beach
# BLEU-4 score: 30.048438849849052
# Real Caption: two children run in the sand along the shore
# Predicted Caption: people walking on the beach
# BLEU-4 score: 54.751825350694524
# Real Caption: two children run towards the lagoon
# Predicted Caption: people walking on the beach
# BLEU-4 score: 13.501633901742352
# Real Caption: two little kids are running through the sand to get to the ocean
# Predicted Caption: people walking on the beach
# BLEU-4 score: 36.70124608961283
# Real Caption: two young children running along a sandy beach
# Predicted Caption: people walking on the beach
# BLEU-4 score: 26.44967217413845
# Real Caption: a group of school children walking around outside in their uniforms
# Predicted Caption: a group of people are standing on a street
# BLEU-4 score: 57.735026918962575
# Real Caption: japanese school children are going to class
# Predicted Caption: a group of people are standing on a street
# BLEU-4 score: 57.735026918962575
# Real Caption: japanese school girls walk down the street
# Predicted Caption: a group of people are standing on a street
# BLEU-4 score: 75.98356856515926
# Real Caption: people walk along on the street
# Predicted Caption: a group of people are standing on a street
# BLEU-4 score: 75.98356856515926
# Real Caption: uniformed schoolgirls are walking together on the street
# Predicted Caption: a group of people are standing on a street
# BLEU-4 score: 22.72544758254965
# Real Caption: a person in a white coat and pink pants snowboards at the snow park
# Predicted Caption: a snowboarder in a red jacket is airborne
# BLEU-4 score: 35.5310106137518
# Real Caption: a person wearing pink pants and a white jacket is snowboarding
# Predicted Caption: a snowboarder in a red jacket is airborne
# BLEU-4 score: 37.84869858133765
# Real Caption: a person wearing pink pants and a white parka at a snow park
# Predicted Caption: a snowboarder in a red jacket is airborne
# BLEU-4 score: 44.6778805361507
# Real Caption: a snowboarder is jumping over a snowbank in a snow park
# Predicted Caption: a snowboarder in a red jacket is airborne
# BLEU-4 score: 74.20884818558929
# Real Caption: a woman in white jacket snowboarding at a park
# Predicted Caption: a snowboarder in a red jacket is airborne
# BLEU-4 score: 45.180100180492246
# Real Caption: a wet dog running in a dry field
# Predicted Caption: a brown and white dog running through the grass
# BLEU-4 score: 29.847458960098226
# Real Caption: black and white dog running outside
# Predicted Caption: a brown and white dog running through the grass
# BLEU-4 score: 29.558013016570783
# Real Caption: the brown and white dog is running though the [UNK]
# Predicted Caption: a brown and white dog running through the grass
# BLEU-4 score: 54.44460596606694
# Real Caption: the dog is running with his tongue hanging out of his mouth
# Predicted Caption: a brown and white dog running through the grass
# BLEU-4 score: 49.9673645033257
# Real Caption: the white and black dog is running through a field
# Predicted Caption: a brown and white dog running through the grass
# BLEU-4 score: 66.8740304976422
# Real Caption: a boy being pulled on a shovel
# Predicted Caption: a baby is holding a red toy in its mouth
# BLEU-4 score: 36.75142442995998
# Real Caption: a happy child play in the scoop of a shovel by a chair in a grassy backyard
# Predicted Caption: a baby is holding a red toy in its mouth
# BLEU-4 score: 68.84677553212491
# Real Caption: a little boy in red flowered shorts is sitting on a shovel
# Predicted Caption: a baby is holding a red toy in its mouth
# BLEU-4 score: 74.00828044922852
# Real Caption: a little boy smiling and riding in a shovel
# Predicted Caption: a baby is holding a red toy in its mouth
# BLEU-4 score: 33.254063990348676
# Real Caption: small boy in red shorts with blue flowers sitting on shovel in the grass near a tan chair
# Predicted Caption: a baby is holding a red toy in its mouth
# BLEU-4 score: 0
# Real Caption: a little brown dog is running in a field
# Predicted Caption: two small dogs run through the grass
# BLEU-4 score: 35.1043582995851
# Real Caption: a little brown dog is running on the grass
# Predicted Caption: two small dogs run through the grass
# BLEU-4 score: 35.64026463354183
# Real Caption: a little brown dog runs through the grass
# Predicted Caption: two small dogs run through the grass
# BLEU-4 score: 26.089939795640397
# Real Caption: a puppy runs in a grassy field a dirt road in the background
# Predicted Caption: two small dogs run through the grass
# BLEU-4 score: 35.79090209118197
# Real Caption: a small brown dog is running over grass littered with dry leaves
# Predicted Caption: two small dogs run through the grass
# BLEU-4 score: 35.08439695638686
# Real Caption: a dog attempting to drink from an outdoor water faucet
# Predicted Caption: a dog lays on his back with his ears on his back
# BLEU-4 score: 35.08439695638686
# Real Caption: a dog drinking out of a water spigot
# Predicted Caption: a dog lays on his back with his ears on his back
# BLEU-4 score: 35.08439695638686
# Real Caption: a dog drinks water out of a water fountain
# Predicted Caption: a dog lays on his back with his ears on his back
# BLEU-4 score: 49.43260319514312
# Real Caption: a hand turns the tap to [UNK] three dogs to drink some water
# Predicted Caption: a dog lays on his back with his ears on his back
# BLEU-4 score: 53.7284965911771
# Real Caption: three dogs drinking water at a public spigot
# Predicted Caption: a dog lays on his back with his ears on his back
# BLEU-4 score: 0
# Real Caption: a white and brown dog with his mouth open and tongue out facing a second almost offcamera dog
# Predicted Caption: two dogs run through the snow
# BLEU-4 score: 3.530681702110927
# Real Caption: two dogs one with long brown fur both dogs have their mouths open and teeth showing one dogs tongue is hanging out
# Predicted Caption: two dogs run through the snow
# BLEU-4 score: 56.23413251903491
# Real Caption: two dogs play in the grass
# Predicted Caption: two dogs run through the snow
# BLEU-4 score: 39.011264866539484
# Real Caption: two furry dogs make [UNK] faces as they play together
# Predicted Caption: two dogs run through the snow
# BLEU-4 score: 75.98356856515926
# Real Caption: two [UNK] dogs fighting
# Predicted Caption: two dogs run through the snow
# BLEU-4 score: 80.91067115702212
# Real Caption: a baseball player slides to the base
# Predicted Caption: a baseball player slides to the ball
# BLEU-4 score: 47.6273899703797
# Real Caption: a catcher tries to beat a runner to home plate
# Predicted Caption: a baseball player slides to the ball
# BLEU-4 score: 80.91067115702212
# Real Caption: a person playing baseball slides for home
# Predicted Caption: a baseball player slides to the ball
# BLEU-4 score: 35.79090209118197
# Real Caption: two baseball players on a field with four spectators and a crowd
# Predicted Caption: a baseball player slides to the ball
# BLEU-4 score: 22.86835008591421
# Real Caption: two men on opposite baseball teams dive for a baseball at homebase
# Predicted Caption: a baseball player slides to the ball
# BLEU-4 score: 75.98356856515926
# Real Caption: a boy rock climbs
# Predicted Caption: a man climbs up a sheer rock cliff face
# BLEU-4 score: 48.54917717073234
# Real Caption: a man is rock climbing without a shirt
# Predicted Caption: a man climbs up a sheer rock cliff face
# BLEU-4 score: 68.65890479690393
# Real Caption: a young boy rock climbing
# Predicted Caption: a man climbs up a sheer rock cliff face
# BLEU-4 score: 54.97775311418521
# Real Caption: the boy looked down as he climbed the steep rock face
# Predicted Caption: a man climbs up a sheer rock cliff face
# BLEU-4 score: 44.02274324685413
# Real Caption: the climber is hanging off a vertical cliff with gear but no shirt
# Predicted Caption: a man climbs up a sheer rock cliff face
# BLEU-4 score: 12.441680005081619
# Real Caption: two children jumping int the sand on a beach the sand is being kicked up and the water is bright blue
# Predicted Caption: a dog is running on the beach
# BLEU-4 score: 19.018379497840193
# Real Caption: two children jump as they run down a large sand dune towards the beach
# Predicted Caption: a dog is running on the beach
# BLEU-4 score: 35.79090209118197
# Real Caption: two girls holding hands and jumping as they walk downhill on beach
# Predicted Caption: a dog is running on the beach
# BLEU-4 score: 36.188990513939245
# Real Caption: two kids running down a sand dune to the beach
# Predicted Caption: a dog is running on the beach
# BLEU-4 score: 52.70837136273565
# Real Caption: two people jump off a sand dune on a beach
# Predicted Caption: a dog is running on the beach
# BLEU-4 score: 63.89431042462724
# Real Caption: an elderly woman is wearing a pink striped shirt
# Predicted Caption: a man holding a hand and a woman in a red shirt in his hand and a store
# BLEU-4 score: 20.10537345406003
# Real Caption: an older woman in a pink striped shirt
# Predicted Caption: a man holding a hand and a woman in a red shirt in his hand and a store
# BLEU-4 score: 63.89431042462724
# Real Caption: an older woman with a striped shirt rubbing her chin
# Predicted Caption: a man holding a hand and a woman in a red shirt in his hand and a store
# BLEU-4 score: 14.879641171245488
# Real Caption: a woman in a pink striped shirt with her hand up
# Predicted Caption: a man holding a hand and a woman in a red shirt in his hand and a store
# BLEU-4 score: 0
# Real Caption: older lady is appears to be getting ready to cover her mouth
# Predicted Caption: a man holding a hand and a woman in a red shirt in his hand and a store
# BLEU-4 score: 58.785603432770436
# Real Caption: a bird has its wings spread very wide and is standing on rocks
# Predicted Caption: a large white bird skates across the top of some white flowers
# BLEU-4 score: 70.71067811865476
# Real Caption: a bird takes off surrounded by large rocks
# Predicted Caption: a large white bird skates across the top of some white flowers
# BLEU-4 score: 75.98356856515926
# Real Caption: a grey bird flies over the water by some rocks
# Predicted Caption: a large white bird skates across the top of some white flowers
# BLEU-4 score: 35.08439695638686
# Real Caption: a large duck in flight over a rocky stream
# Predicted Caption: a large white bird skates across the top of some white flowers
# BLEU-4 score: 53.7284965911771
# Real Caption: a [UNK] is flying over rocks
# Predicted Caption: a large white bird skates across the top of some white flowers
# BLEU-4 score: 14.872972167876735
# Real Caption: a woman crouches down next to her terrier dog to smile at a little girl sitting on the sidewalk
# Predicted Caption: two children are sitting on a body of water
# BLEU-4 score: 29.642151188002913
# Real Caption: a woman in a red top and a small dog talks to a young girl
# Predicted Caption: two children are sitting on a body of water
# BLEU-4 score: 57.735026918962575
# Real Caption: a woman showing a small dog to an infant
# Predicted Caption: two children are sitting on a body of water
# BLEU-4 score: 41.36895450425725
# Real Caption: a woman squatting to face a small child while holding a dog
# Predicted Caption: two children are sitting on a body of water
# BLEU-4 score: 28.22651961477009
# Real Caption: a woman with a brown dog is talking to a toddler who is sat on the ground
# Predicted Caption: two children are sitting on a body of water
# BLEU-4 score: 22.230037854975045
# Real Caption: a brown dog is soaked and is walking out of the water
# Predicted Caption: a dog runs through the water
# BLEU-4 score: 60.82887289096036
# Real Caption: a dog walks out of the water
# Predicted Caption: a dog runs through the water
# BLEU-4 score: 51.0029457493824
# Real Caption: a long brown haired dog walking through a river
# Predicted Caption: a dog runs through the water
# BLEU-4 score: 31.024517040537297
# Real Caption: a very wet brown dog is emerging from the water
# Predicted Caption: a dog runs through the water
# BLEU-4 score: 43.29820146406897
# Real Caption: a wet dog walks out of the water
# Predicted Caption: a dog runs through the water
# BLEU-4 score: 18.69315914320289
# Real Caption: a little boy in a red jacket plays on a jungle gym
# Predicted Caption: two kids playing on a swing
# BLEU-4 score: 40.02764942449165
# Real Caption: a little boy playing on a playground
# Predicted Caption: two kids playing on a swing
# BLEU-4 score: 39.011264866539484
# Real Caption: a small black child plays on an outdoor jungle gym
# Predicted Caption: two kids playing on a swing
# BLEU-4 score: 9.597387912920984
# Real Caption: a young boy in a black sweatshirt and red vest plays on a red jungle gym
# Predicted Caption: two kids playing on a swing
# BLEU-4 score: 50.813274815461476
# Real Caption: boy playing on some metal bars
# Predicted Caption: two kids playing on a swing
# BLEU-4 score: 24.601580968354604
# Real Caption: a bearded man wears a red bandanna and a leather jacket over a teeshirt with an american flag on it
# Predicted Caption: a group of people are hugging and using hand signs
# BLEU-4 score: 34.1077254951379
# Real Caption: a man dressed in black leather with a red bandanna is smiling at the camera
# Predicted Caption: a group of people are hugging and using hand signs
# BLEU-4 score: 56.23413251903491
# Real Caption: a man wearing a leather jacket
# Predicted Caption: a group of people are hugging and using hand signs
# BLEU-4 score: 54.751825350694524
# Real Caption: a man wearing a red headband and a leather outfit standing outside
# Predicted Caption: a group of people are hugging and using hand signs
# BLEU-4 score: 60.51012508914459
# Real Caption: a man with a beard red headband and leather vest smiles
# Predicted Caption: a group of people are hugging and using hand signs
# BLEU-4 score: 34.172334076593074
# Real Caption: a large yellow dog and a small white dog in the grass
# Predicted Caption: a brown dog and a woman are all with a white dog
# BLEU-4 score: 31.61070566601305
# Real Caption: a small light tan dog is running past a large brown dog standing in the grass
# Predicted Caption: a brown dog and a woman are all with a white dog
# BLEU-4 score: 60.76795808137692
# Real Caption: a small white dog and large brown dog play on the grass
# Predicted Caption: a brown dog and a woman are all with a white dog
# BLEU-4 score: 49.61683000340363
# Real Caption: the large brown dog faces the little white dog on the grass
# Predicted Caption: a brown dog and a woman are all with a white dog
# BLEU-4 score: 53.7284965911771
# Real Caption: two dogs playing in a yard
# Predicted Caption: a brown dog and a woman are all with a white dog
# BLEU-4 score: 25.526076207555658
# Real Caption: seven people are posing over a structure that extends over a watery area and ocean
# Predicted Caption: two people are wading in the water with black shoes off
# BLEU-4 score: 72.26568811456053
# Real Caption: seven people jumping into the clear blue water
# Predicted Caption: two people are wading in the water with black shoes off
# BLEU-4 score: 65.29942057256105
# Real Caption: seven people jumping into water
# Predicted Caption: two people are wading in the water with black shoes off
# BLEU-4 score: 40.637982820134425
# Real Caption: seven people jump into the water
# Predicted Caption: two people are wading in the water with black shoes off
# BLEU-4 score: 65.9858515800358
# Real Caption: seven people leaping into the air over a walk over blue water
# Predicted Caption: two people are wading in the water with black shoes off
# BLEU-4 score: 52.70837136273565
# Real Caption: a child in yellow overalls is walking over packed dirt
# Predicted Caption: a young child is running on pavement
# BLEU-4 score: 60.80253214198359
# Real Caption: a child without a shirt running in the dirt
# Predicted Caption: a young child is running on pavement
# BLEU-4 score: 41.28713178810563
# Real Caption: a little boy in overalls runs fast on a dirt trail
# Predicted Caption: a young child is running on pavement
# BLEU-4 score: 80.91067115702212
# Real Caption: a small child in overalls running
# Predicted Caption: a young child is running on pavement
# BLEU-4 score: 19.018379497840193
# Real Caption: a toddler is running down the path with an orange toy in his hand
# Predicted Caption: a young child is running on pavement
# BLEU-4 score: 63.89431042462724
# Real Caption: three people drive atvs
# Predicted Caption: two people on a racing circuit
# BLEU-4 score: 10.62125567958006
# Real Caption: three people on atvs in a brown field turn their heads to look at the camera
# Predicted Caption: two people on a racing circuit
# BLEU-4 score: 50.813274815461476
# Real Caption: three people on atv s outside
# Predicted Caption: two people on a racing circuit
# BLEU-4 score: 28.871566309219897
# Real Caption: three people on four wheel atv s in a field
# Predicted Caption: two people on a racing circuit
# BLEU-4 score: 38.75385825373295
# Real Caption: three people ride their four wheelers through the field
# Predicted Caption: two people on a racing circuit
# BLEU-4 score: 34.90881360123862
# Real Caption: a brown dog runs towards the camera on a dirt trail with mountains in the background
# Predicted Caption: a golden retriever is running in a grassy area
# BLEU-4 score: 25.01325796027163
# Real Caption: a brown dog runs toward the camera down a rocky trail through the brush with mountains in the background
# Predicted Caption: a golden retriever is running in a grassy area
# BLEU-4 score: 81.6496580927726
# Real Caption: a dog running on a trail in the mountains
# Predicted Caption: a golden retriever is running in a grassy area
# BLEU-4 score: 33.12566919112253
# Real Caption: the brown dog is walking along the dirt path with beautiful mountains behind him
# Predicted Caption: a golden retriever is running in a grassy area
# BLEU-4 score: 45.180100180492246
# Real Caption: yellow dog is running up a trail
# Predicted Caption: a golden retriever is running in a grassy area
# BLEU-4 score: 51.93071778680676
# Real Caption: a bulldog jumps over a log next to a stream
# Predicted Caption: a black and white dog jumping over a stream of trees
# BLEU-4 score: 27.717894910947205
# Real Caption: a dog is pawing at a fallen log nearby a stream in an area with [UNK]
# Predicted Caption: a black and white dog jumping over a stream of trees
# BLEU-4 score: 23.462350320528
# Real Caption: black and white dog grabs tree limb
# Predicted Caption: a black and white dog jumping over a stream of trees
# BLEU-4 score: 23.708987804092637
# Real Caption: the black and white dog jumps by a log near a creek
# Predicted Caption: a black and white dog jumping over a stream of trees
# BLEU-4 score: 54.91004867761124
# Real Caption: the dog plays with the large log
# Predicted Caption: a black and white dog jumping over a stream of trees
# BLEU-4 score: 7.734979095357068
# Real Caption: a black dog leaps from the bank into a body of water with a field of dry grass in the background
# Predicted Caption: a black dog is running through shallow water
# BLEU-4 score: 25.19230697765312
# Real Caption: a black dog with a blue collar is jumping into the water
# Predicted Caption: a black dog is running through shallow water
# BLEU-4 score: 29.877899455445572
# Real Caption: a black lab runs headlong into a lake surrounded by farmland
# Predicted Caption: a black dog is running through shallow water
# BLEU-4 score: 15.238608850315924
# Real Caption: the black dog is running down the grassy [UNK] to jump in the water below
# Predicted Caption: a black dog is running through shallow water
# BLEU-4 score: 43.47208719449914
# Real Caption: the dog is jumping into the lake
# Predicted Caption: a black dog is running through shallow water
# BLEU-4 score: 19.674979811155634
# Real Caption: a child in a bathing suit plays in a sprinkler
# Predicted Caption: a girl in a bathing suit jumps off the edge of a water slide
# BLEU-4 score: 61.47881529512643
# Real Caption: a child plays in backyard sprinklers
# Predicted Caption: a girl in a bathing suit jumps off the edge of a water slide
# BLEU-4 score: 11.75404023495381
# Real Caption: a child seen from the waist down in a bathing suit standing on a slip and slide with [UNK] of water shooting up
# Predicted Caption: a girl in a bathing suit jumps off the edge of a water slide
# BLEU-4 score: 35.83129187641354
# Real Caption: a kid standing in a sprinkler
# Predicted Caption: a girl in a bathing suit jumps off the edge of a water slide
# BLEU-4 score: 51.697315395717055
# Real Caption: child standing on yellow sprinkler mat with water spraying
# Predicted Caption: a girl in a bathing suit jumps off the edge of a water slide
# BLEU-4 score: 38.503228868787126
# Real Caption: a little boy is splashing around in the water in a kiddie pool
# Predicted Caption: a small baby girl sits in the grass holding an object in its mouth
# BLEU-4 score: 40.71220775553065
# Real Caption: a small boy in a blue shirt splashes water in a baby pool outside
# Predicted Caption: a small baby girl sits in the grass holding an object in its mouth
# BLEU-4 score: 45.788313721339826
# Real Caption: a small boy wearing a blue shirt plays in the kiddie pool
# Predicted Caption: a small baby girl sits in the grass holding an object in its mouth
# BLEU-4 score: 35.83129187641354
# Real Caption: a young boy paying in a small pool with water
# Predicted Caption: a small baby girl sits in the grass holding an object in its mouth
# BLEU-4 score: 61.47881529512643
# Real Caption: a young child splashes in a green and yellow wading pool
# Predicted Caption: a small baby girl sits in the grass holding an object in its mouth
# BLEU-4 score: 42.728700639623405
# Real Caption: a little girl is falling backwards onto a bed
# Predicted Caption: a little boy is running very high in the air
# BLEU-4 score: 56.23413251903491
# Real Caption: a young girl jumps on a bed
# Predicted Caption: a little boy is running very high in the air
# BLEU-4 score: 66.8740304976422
# Real Caption: the young girl is happily standing inside the house
# ...
# Predicted Caption: two people are looking at an object in the same room
# BLEU-4 score: 45.781413316608585
# Real Caption: man dressed up in black and brown and holding a white light saber
# Predicted Caption: two people are looking at an object in the same room
# BLEU-4 score: 54.91004867761124
# Real Caption: the man holds a light [UNK]
# Predicted Caption: two people are looking at an object in the same room
# BLEU-4 score: 54.91004867761124
# Real Caption: the man is playing with his star [UNK] light sword
# Predicted Caption: two people are looking at an object in the same room
# BLEU-4 score: 84.08964152537145
# Real Caption: a black dog running on grass
# Predicted Caption: a dog runs through the grass
# BLEU-4 score: 60.653065971263345
# Real Caption: a dog runs through the grass towards the camera
# Predicted Caption: a dog runs through the grass
# BLEU-4 score: 26.185785468823504
# Real Caption: a large dog running on grass with a tennis ball in his mouth
# Predicted Caption: a dog runs through the grass
# BLEU-4 score: 10.215406126626542
# Real Caption: a large gray dog carrying a ball in its mouth runs across the grass towards the camera
# Predicted Caption: a dog runs through the grass
# BLEU-4 score: 15.82341759519314
# Real Caption: the grey dog is jumping through the grass with water in the background
# Predicted Caption: a dog runs through the grass
# BLEU-4 score: 69.64705665515709
# Real Caption: three people are standing on a hill that is partly covered in snow
# Predicted Caption: a man and a dog are playing with a dog on the side of a snowy hill
# BLEU-4 score: 58.56596027429395
# Real Caption: three people in dark clothing stand in a field of melting snow
# Predicted Caption: a man and a dog are playing with a dog on the side of a snowy hill
# BLEU-4 score: 29.282980137146968
# Real Caption: three people standing on the side of a snowy grassy hill
# Predicted Caption: a man and a dog are playing with a dog on the side of a snowy hill
# BLEU-4 score: 49.24790605054523
# Real Caption: three young men standing on partially snowcovered ground
# Predicted Caption: a man and a dog are playing with a dog on the side of a snowy hill
# BLEU-4 score: 49.24790605054523
# Real Caption: two boys watch a third boy kicking some snow
# Predicted Caption: a man and a dog are playing with a dog on the side of a snowy hill
# BLEU-4 score: 27.768352844338136
# Real Caption: a man in a red uniform jumps towards a soccer ball
# Predicted Caption: two teams of players playing soccer
# BLEU-4 score: 10.215406126626542
# Real Caption: a soccer participant is trying to hit a ball while an opposing team member runs behind him
# Predicted Caption: two teams of players playing soccer
# BLEU-4 score: 38.75385825373295
# Real Caption: a soccer player hitting the ball with his head
# Predicted Caption: two teams of players playing soccer
# BLEU-4 score: 27.768352844338136
# Real Caption: soccer player in red dives toward ball blocking player in blue
# Predicted Caption: two teams of players playing soccer
# BLEU-4 score: 14.446765889424462
# Real Caption: two soccer players [UNK] as one tries to get the ball in front of the other player
# Predicted Caption: two teams of players playing soccer
# BLEU-4 score: 61.47881529512643
# Real Caption: a bicyclist catches some air
# Predicted Caption: a person on a bike is airborne
# BLEU-4 score: 5.183064822444717
# Real Caption: a helmeted boy on a bike flies through the air as he rides among dirt hills with a river in the background
# Predicted Caption: a person on a bike is airborne
# BLEU-4 score: 59.888272317301194
# Real Caption: a man is doing a stunt outside on his bike
# Predicted Caption: a person on a bike is airborne
# BLEU-4 score: 35.79090209118197
# Real Caption: bike rider doing a high jump over hilly track water in background
# Predicted Caption: a person on a bike is airborne
# BLEU-4 score: 33.171255015277175
# Real Caption: this helmeted person is doing a stunt on a bicycle outdoors
# Predicted Caption: a person on a bike is airborne
# BLEU-4 score: 38.503228868787126
# Real Caption: a person in a black jacket doing tricks on a motorbike
# Predicted Caption: a person wearing a red and white shirt riding a bike through the air
# BLEU-4 score: 48.41524713034601
# Real Caption: a person on a bike doing a wheelie on a rock
# Predicted Caption: a person wearing a red and white shirt riding a bike through the air
# BLEU-4 score: 38.503228868787126
# Real Caption: a person on a motorcycle doing a wheelie off of a rock
# Predicted Caption: a person wearing a red and white shirt riding a bike through the air
# BLEU-4 score: 38.503228868787126
# Real Caption: a person rides their bicycle onto a rock and balances on one wheel
# Predicted Caption: a person wearing a red and white shirt riding a bike through the air
# BLEU-4 score: 35.83129187641354
# Real Caption: the man is riding a motorcycle over jagged rocks
# Predicted Caption: a person wearing a red and white shirt riding a bike through the air
# BLEU-4 score: 36.72056269893593
# Real Caption: a baby looks through his crib
# Predicted Caption: a baby is smiling whilst playing in a little [UNK] playground
# BLEU-4 score: 40.637982820134425
# Real Caption: a baby surrounded by some toys looks out of a playpen
# Predicted Caption: a baby is smiling whilst playing in a little [UNK] playground
# BLEU-4 score: 65.29942057256105
# Real Caption: baby in playpen with wide eyes
# Predicted Caption: a baby is smiling whilst playing in a little [UNK] playground
# BLEU-4 score: 54.91004867761124
# Real Caption: baby looking through playpen bars at camera
# Predicted Caption: a baby is smiling whilst playing in a little [UNK] playground
# BLEU-4 score: 28.249247019794392
# Real Caption: the infant is laying on its stomach in a crib looking up at the camera
# Predicted Caption: a baby is smiling whilst playing in a little [UNK] playground
# BLEU-4 score: 38.827267775222325
# Real Caption: a black sheep with three white dogs
# Predicted Caption: two white dogs and one black and white run across the grass
# BLEU-4 score: 38.827267775222325
# Real Caption: four white dogs are standing beside a black sheep
# Predicted Caption: two white dogs and one black and white run across the grass
# BLEU-4 score: 41.722614486115056
# Real Caption: the white dogs look curiously at the black llama
# Predicted Caption: two white dogs and one black and white run across the grass
# BLEU-4 score: 38.827267775222325
# Real Caption: three white dogs are near a black llama
# Predicted Caption: two white dogs and one black and white run across the grass
# BLEU-4 score: 35.08439695638686
# Real Caption: white dogs stand near a sheep or llama
# Predicted Caption: two white dogs and one black and white run across the grass
# BLEU-4 score: 54.44460596606694
# Real Caption: a guy sitting on the side of the road playing an accordion
# Predicted Caption: two people on a street walk down the street
# BLEU-4 score: 61.43868746168435
# Real Caption: a man is playing the accordion in an empty park
# Predicted Caption: two people on a street walk down the street
# BLEU-4 score: 29.642151188002913
# Real Caption: a man sits by a driveway in front of a white building playing an accordion
# Predicted Caption: two people on a street walk down the street
# BLEU-4 score: 57.735026918962575
# Real Caption: a man with an accordion sitting alongside a path
# Predicted Caption: two people on a street walk down the street
# BLEU-4 score: 33.03164318013807
# Real Caption: older man playing accordion on a street
# Predicted Caption: two people on a street walk down the street
# BLEU-4 score: 26.261686698372262
# Real Caption: a brown dog is running in the water by the beach
# Predicted Caption: a dog walking through the water
# BLEU-4 score: 71.18034480382983
# Real Caption: a brown dog jumps in the ocean
# Predicted Caption: a dog walking through the water
# BLEU-4 score: 64.31870218238024
# Real Caption: a brown dog runs down a beach
# Predicted Caption: a dog walking through the water
# BLEU-4 score: 39.2703811972245
# Real Caption: a brown dog wearing a collar is running through some water
# Predicted Caption: a dog walking through the water
# BLEU-4 score: 59.46035575013605
# Real Caption: a dog running through the water
# Predicted Caption: a dog walking through the water
# BLEU-4 score: 63.89431042462724
# Real Caption: a man wearing goggles snowboards on a half pipe
# Predicted Caption: a person in a green jacket and a black helmet is skiing
# BLEU-4 score: 41.722614486115056
# Real Caption: a person on a yellow snowboard does some tricks in the snow
# Predicted Caption: a person in a green jacket and a black helmet is skiing
# BLEU-4 score: 63.89431042462724
# Real Caption: person snowboarding at a ski slope
# Predicted Caption: a person in a green jacket and a black helmet is skiing
# BLEU-4 score: 70.71067811865476
# Real Caption: the snowboarder in the blue pants is performing a trick
# Predicted Caption: a person in a green jacket and a black helmet is skiing
# BLEU-4 score: 37.34363629657559
# Real Caption: the snowboarder is wearing a dark top blue pants and a helmet with goggles
# Predicted Caption: a person in a green jacket and a black helmet is skiing
# BLEU-4 score: 62.401954419369154
# Real Caption: a hiker is climbing up a very steep mountain
# Predicted Caption: a person is in the mountains and sky
# BLEU-4 score: 55.06953149031838
# Real Caption: a male hiker carries his gear up the snowy mountain
# Predicted Caption: a person is in the mountains and sky
# BLEU-4 score: 59.46035575013605
# Real Caption: a man hikes up a huge mountain
# Predicted Caption: a person is in the mountains and sky
# BLEU-4 score: 42.88819424803535
# Real Caption: hiker in blue shirt and red shorts stands on hill near mountain
# Predicted Caption: a person is in the mountains and sky
# BLEU-4 score: 78.25422900366436
# Real Caption: the man is hiking up a grassy mountainside
# Predicted Caption: a person is in the mountains and sky
# BLEU-4 score: 37.23909894939823
# Real Caption: a man in yellow stands in a garbage strewn [UNK]
# Predicted Caption: people are pushing a cart a man and two men outside a store
# BLEU-4 score: 40.01601601922499
# Real Caption: a man stands near garbage and a spray painted drawing
# Predicted Caption: people are pushing a cart a man and two men outside a store
# BLEU-4 score: 27.239398235793654
# Real Caption: a man wearing a yellow shirt is standing in front of a cement wall with drawings on it
# Predicted Caption: people are pushing a cart a man and two men outside a store
# BLEU-4 score: 26.669676296222256
# Real Caption: a man wearing a yellow shirt standing in the middle of a bunch of garbage and a graffitied wall
# Predicted Caption: people are pushing a cart a man and two men outside a store
# BLEU-4 score: 37.23909894939823
# Real Caption: a man wearing a yellow shirt standing near some refuse
# Predicted Caption: people are pushing a cart a man and two men outside a store
# BLEU-4 score: 37.90562132075204
# Real Caption: a man dressing in a black shirt is waiting to cross the street with traffic
# Predicted Caption: two people are riding on a street with cars and buildings in the background
# BLEU-4 score: 61.47881529512643
# Real Caption: a man standing in a crosswalk
# Predicted Caption: two people are riding on a street with cars and buildings in the background
# BLEU-4 score: 51.697315395717055
# Real Caption: a man waiting for traffic to stop at road crossing
# Predicted Caption: two people are riding on a street with cars and buildings in the background
# BLEU-4 score: 17.77835117834348
# Real Caption: an asian man tries to [UNK] on a street with heavy traffic
# Predicted Caption: two people are riding on a street with cars and buildings in the background
# BLEU-4 score: 51.697315395717055
# Real Caption: man waits for [UNK] to pass before crossing the wet road
# Predicted Caption: two people are riding on a street with cars and buildings in the background
# BLEU-4 score: 54.97775311418521
# Real Caption: a couple standing outside in the dark near some festive lights
# Predicted Caption: a person wearing a blue headscarf sits near [UNK]
# BLEU-4 score: 68.65890479690393
# Real Caption: beautiful lights [UNK] trees on a dark night
# Predicted Caption: a person wearing a blue headscarf sits near [UNK]
# BLEU-4 score: 39.39328149130935
# Real Caption: two men meet by a fountain engulfed in lights they are wearing winter coats
# Predicted Caption: a person wearing a blue headscarf sits near [UNK]
# BLEU-4 score: 51.66357204442371
# Real Caption: two people stand looking at a light sculpture at night
# Predicted Caption: a person wearing a blue headscarf sits near [UNK]
# BLEU-4 score: 44.02274324685413
# Real Caption: two people wearing black are standing in front of a lit up statue
# Predicted Caption: a person wearing a blue headscarf sits near [UNK]
# BLEU-4 score: 46.04207397758504
# Real Caption: a dirt bike rider jumps into the air and does a trick
# Predicted Caption: a person riding a dirt bike jumps up into the air
# BLEU-4 score: 54.91004867761124
# Real Caption: a guy doing tricks on his motorcycle next to fireworks
# Predicted Caption: a person riding a dirt bike jumps up into the air
# BLEU-4 score: 21.50616268006498
# Real Caption: a lone motorcyclist jumping in midair with his legs in the air and sparks flying in the background
# Predicted Caption: a person riding a dirt bike jumps up into the air
# BLEU-4 score: 65.29942057256105
# Real Caption: a motorcycle daredevil making a high jump
# Predicted Caption: a person riding a dirt bike jumps up into the air
# BLEU-4 score: 28.009266907237095
# Real Caption: a stunt man does a bike trick up in the air while fireworks go off around him
# Predicted Caption: a person riding a dirt bike jumps up into the air
# BLEU-4 score: 26.089939795640397
# Real Caption: a man in a white tshirt is standing outside on a busy street
# Predicted Caption: many people are walking down the street
# BLEU-4 score: 26.896050220204014
# Real Caption: a man stands on a busy street with buildings and shops in the background
# Predicted Caption: many people are walking down the street
# BLEU-4 score: 0
# Real Caption: a picture of a young man in front of some interesting buildings
# Predicted Caption: many people are walking down the street
# BLEU-4 score: 61.47881529512643
# Real Caption: man poses on street corner
# Predicted Caption: many people are walking down the street
# BLEU-4 score: 0
# Real Caption: man with white shirt and green shorts poses for a picture
# Predicted Caption: many people are walking down the street
# BLEU-4 score: 48.549177170732335
# Real Caption: a clown [UNK] cutout pictures of children
# Predicted Caption: a girl in a yellow jacket and a white shirt is holding a white leash to a dog
# BLEU-4 score: 57.735026918962575
# Real Caption: a dirty looking clown holding up two paper cut [UNK] of children with blond hair
# Predicted Caption: a girl in a yellow jacket and a white shirt is holding a white leash to a dog
# BLEU-4 score: 35.75297164449809
# Real Caption: a man wearing a balloon hat and a grassy shirt holds up two large paper [UNK]
# Predicted Caption: a girl in a yellow jacket and a white shirt is holding a white leash to a dog
# BLEU-4 score: 57.735026918962575
# Real Caption: a man wearing a balloon hat holds up colored cutout drawings of two men
# Predicted Caption: a girl in a yellow jacket and a white shirt is holding a white leash to a dog
# BLEU-4 score: 48.549177170732335
# Real Caption: the man wears balloons on his head and holds paper people
# Predicted Caption: a girl in a yellow jacket and a white shirt is holding a white leash to a dog
# BLEU-4 score: 22.230037854975045
# Real Caption: two brown and black dogs run through the dry grass
# Predicted Caption: two dogs run through field
# BLEU-4 score: 41.71622699855093
# Real Caption: two dogs are running in a field
# Predicted Caption: two dogs run through field
# BLEU-4 score: 33.16331950155214
# Real Caption: two dogs run around together in the field
# Predicted Caption: two dogs run through field
# BLEU-4 score: 50.95231471606585
# Real Caption: two dogs running through high grass
# Predicted Caption: two dogs run through field
# BLEU-4 score: 48.301556221513735
# Real Caption: two large dogs frolic in a grassy field
# Predicted Caption: two dogs run through field
# 0.43601795578132774

# %% [markdown]
# ## Try it on your own images
#
# For fun, below you're provided a method you can use to caption your own images with the model you've just trained. Keep in mind, it was trained on a relatively small amount of data, and your images may be different from the training data (so be prepared for weird results!)

# %%
image_url = 'https://tensorflow.org/images/surf.jpg'
image_extension = image_url[-4:]
image_path = tf.keras.utils.get_file('image'+image_extension, origin=image_url)

result, attention_plot = evaluate(image_path)
print('Prediction Caption:', ' '.join(result))
plot_attention(image_path, result, attention_plot)
# opening the image
Image.open(image_path)
# Out:
# Downloading data from https://tensorflow.org/images/surf.jpg
# 65536/64400 [==============================] - 0s 3us/step
# 73728/64400 [==================================] - 0s 3us/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-35-01b50c44953e> in <module>()
#       3 image_path = tf.keras.utils.get_file('image'+image_extension, origin=image_url)
#       4
# ----> 5 result, attention_plot = evaluate(image_path)
#       6 print('Prediction Caption:', ' '.join(result))
#       7 plot_attention(image_path, result, attention_plot)
#
# ValueError: too many values to unpack (expected 2)

# %% [markdown]
# # Next steps
#
# Congrats! You've just trained an image captioning model with attention. Next, take a look at this example [Neural Machine Translation with Attention](https://www.tensorflow.org/text/tutorials/nmt_with_attention). It uses a similar architecture to translate between Spanish and English sentences. You can also experiment with training the code in this notebook on a different dataset.
